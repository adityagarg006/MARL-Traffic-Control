# %%
# CELL 1: Imports and Environment Setup
import os
import random
import json
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# New Graph Imports
from torch_geometric.nn import GATConv
from torch_geometric.utils import add_self_loops

import gym
import cityflow
import gym_cityflow

hardware_device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Active Compute Device: {hardware_device}")
# Out:
# Active Compute Device: cuda

# %%
# CELL 2: Graph Architecture and Environment Parsing

def build_city_graph(config_path):
    """Parses the roadnet JSON to build the mathematical graph (edge_index) of intersections."""
    cfg = json.load(open(config_path, "r"))
    roadnet_path = os.path.join(cfg["dir"], cfg["roadnetFile"])
    roadnet = json.load(open(roadnet_path, "r"))

    # Find valid intersections
    valid_nodes = sorted([node["id"] for node in roadnet["intersections"] if not node.get("virtual", False)])
    node_to_index = {node: idx for idx, node in enumerate(valid_nodes)}

    # Map the roads (edges)
    edge_list = []
    for road in roadnet["roads"]:
        start_node = road.get("startIntersection")
        end_node = road.get("endIntersection")
        if start_node in node_to_index and end_node in node_to_index:
            u, v = node_to_index[start_node], node_to_index[end_node]
            edge_list.append([u, v])
            edge_list.append([v, u]) # Bidirectional traffic

    # Convert to PyTorch tensor and add self-loops (so agents consider their own traffic)
    tensor_edges = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
    # tensor_edges, _ = add_self_loops(tensor_edges, num_nodes=len(valid_nodes))
    
    return tensor_edges, len(valid_nodes)


class AttentionGraphTrafficBrain(nn.Module):
    """GAT-Dueling Architecture: Agents share info before calculating Value/Advantage."""
    def __init__(self, features_in, num_actions, shared_dims=[64, 64], split_dim=32, heads=4):
        super(AttentionGraphTrafficBrain, self).__init__()
        
        # 1. Graph Attention Layers (The Trunk)
        self.gat_layer_1 = GATConv(features_in, shared_dims[0], heads=heads, concat=True)
        self.gat_layer_2 = GATConv(shared_dims[0] * heads, shared_dims[1], heads=1, concat=False)
        
        # 2. Value Stream [V(s)]
        self.value_head = nn.Sequential(
            nn.Linear(shared_dims[1], split_dim),
            nn.LayerNorm(split_dim),
            nn.ReLU(inplace=True),
            nn.Linear(split_dim, 1)
        )
        
        # 3. Advantage Stream [A(s, a)]
        self.advantage_head = nn.Sequential(
            nn.Linear(shared_dims[1], split_dim),
            nn.LayerNorm(split_dim),
            nn.ReLU(inplace=True),
            nn.Linear(split_dim, num_actions)
        )

    def forward(self, x, edge_idx):
        # Route traffic data through the graph network
        hidden = F.elu(self.gat_layer_1(x, edge_idx))
        hidden = F.elu(self.gat_layer_2(hidden, edge_idx))
        
        # Calculate Dueling Q-Values
        state_value = self.value_head(hidden)
        action_advantages = self.advantage_head(hidden)
        
        q_predictions = state_value + (action_advantages - action_advantages.mean(dim=1, keepdim=True))
        return q_predictions


class RunningRewardScaler:
    # KEEP YOUR EXISTING REWARD SCALER CODE HERE (No changes needed)
    def __init__(self, decay_rate=0.001, epsilon=1e-8):
        self.running_mean = 0.0
        self.running_variance = 1.0
        self.decay_rate = decay_rate
        self.epsilon = epsilon

    def scale(self, reward_array):
        current_mean = np.mean(reward_array)
        current_var = np.var(reward_array)
        self.running_mean += self.decay_rate * (current_mean - self.running_mean)
        self.running_variance += self.decay_rate * (current_var - self.running_variance)
        return (reward_array - self.running_mean) / (np.sqrt(self.running_variance) + self.epsilon)

# %%
# CELL 3: Graph-Aware Experience Replay
class GraphExperienceMemory:
    """Stores FULL graphs (all agents simultaneously) so GAT can route messages."""
    def __init__(self, max_capacity, num_agents, feature_dim):
        self.capacity = max_capacity
        self.num_agents = num_agents
        self.ptr = 0
        self.current_count = 0
        
        # Note the extra dimension to preserve the 16-agent graph structure
        self.s_mem = np.zeros((max_capacity, num_agents, feature_dim), dtype=np.float32)
        self.s_next_mem = np.zeros((max_capacity, num_agents, feature_dim), dtype=np.float32)
        self.a_mem = np.zeros((max_capacity, num_agents), dtype=np.int64)
        self.r_mem = np.zeros((max_capacity, num_agents), dtype=np.float32)
        self.done_mem = np.zeros(max_capacity, dtype=np.float32)

    def add_graph_transition(self, states, actions, next_states, rewards, done_flag):
        # Ingests the entire city state as a single interconnected snapshot
        self.s_mem[self.ptr] = states
        self.a_mem[self.ptr] = actions
        self.s_next_mem[self.ptr] = next_states
        self.r_mem[self.ptr] = rewards
        self.done_mem[self.ptr] = float(done_flag)
        
        self.ptr = (self.ptr + 1) % self.capacity
        self.current_count = min(self.current_count + 1, self.capacity)

    def draw_batch(self, sample_size):
        indices = np.random.randint(0, self.current_count, size=sample_size)
        return (
            self.s_mem[indices],
            self.a_mem[indices],
            self.r_mem[indices],
            self.s_next_mem[indices],
            self.done_mem[indices]
        )

    def __len__(self):
        return self.current_count

# %%
# CELL 4: Central Multi-Agent Graph Coordinator
class GlobalTrafficCoordinator:
    def __init__(self, state_size, action_size, total_agents, config, base_graph_edges):
        self.action_size = action_size
        self.cfg = config
        self.total_agents = total_agents
        self.base_graph_edges = base_graph_edges.to(hardware_device)
        
        self.explore_rate = config['initial_eps']
        self.explore_floor = config['min_eps']
        self.explore_decay = config['decay_eps']
        
        self.reward_processor = RunningRewardScaler()
        # Initialize the new Graph-Aware Memory
        self.memory = GraphExperienceMemory(config['buffer_limit'], total_agents, state_size)
        
        # Initialize Graph Networks
        self.policy_net = AttentionGraphTrafficBrain(state_size, action_size).to(hardware_device)
        self.stable_net = AttentionGraphTrafficBrain(state_size, action_size).to(hardware_device)
        self.stable_net.load_state_dict(self.policy_net.state_dict())
        self.stable_net.eval()
        
        self.opt = optim.Adam(self.policy_net.parameters(), lr=config['learning_rate'])
        self.interaction_steps = 0

    def pick_actions(self, observations):
        state_t = torch.tensor(np.array(observations), dtype=torch.float32, device=hardware_device)
        with torch.no_grad():
            predictions = self.policy_net(state_t, self.base_graph_edges)
            
        chosen_actions = []
        for i in range(self.total_agents):
            if random.random() < self.explore_rate:
                chosen_actions.append(random.randrange(self.action_size))
            else:
                chosen_actions.append(predictions[i].argmax().item())
        return chosen_actions

    def record_and_train(self, s, a, s_next, r, is_done):
        r_array = np.array(r, dtype=np.float32)
        scaled_r = self.reward_processor.scale(r_array)
        
        # Pass the entire 16-agent lists at once
        self.memory.add_graph_transition(s, a, s_next, scaled_r, is_done)
        
        self.interaction_steps += 1
        if len(self.memory) >= self.cfg['batch_sz'] and self.interaction_steps % self.cfg['update_freq'] == 0:
            self._optimize_weights()
            
        if self.interaction_steps % self.cfg['sync_freq'] == 0:
            self.stable_net.load_state_dict(self.policy_net.state_dict())

    def decay_exploration(self):
        self.explore_rate = max(self.explore_floor, self.explore_rate * self.explore_decay)

    def _build_batch_edges(self, batch_sz):
        """Fixes PyG batching by tiling the graph edges across the batch dimension."""
        num_edges = self.base_graph_edges.shape[1]
        batched_edges = self.base_graph_edges.repeat(1, batch_sz)
        offsets = torch.arange(batch_sz, device=hardware_device).repeat_interleave(num_edges) * self.total_agents
        return batched_edges + offsets

    def _optimize_weights(self):
        s_b, a_b, r_b, s_next_b, done_b = self.memory.draw_batch(self.cfg['batch_sz'])
        batch_sz = s_b.shape[0]
        
        # Flatten the graphs sequentially for PyTorch Geometric (Batch Size * 16 Agents)
        states = torch.FloatTensor(s_b.reshape(-1, self.cfg['state_dim'])).to(hardware_device)
        next_states = torch.FloatTensor(s_next_b.reshape(-1, self.cfg['state_dim'])).to(hardware_device)
        actions = torch.LongTensor(a_b.reshape(-1, 1)).to(hardware_device)
        rewards = torch.FloatTensor(r_b.reshape(-1, 1)).to(hardware_device)
        
        # Dones apply to the whole graph, so we repeat the flag for all 16 agents
        repeated_dones = np.repeat(done_b, self.total_agents)
        dones = torch.FloatTensor(repeated_dones.reshape(-1, 1)).to(hardware_device)

        # Generate block-diagonal edges for the batch
        batch_edge_index = self._build_batch_edges(batch_sz)

        # Double DQN + GAT Target Calculation
        current_q = self.policy_net(states, batch_edge_index).gather(1, actions)
        with torch.no_grad():
            best_future_actions = self.policy_net(next_states, batch_edge_index).argmax(dim=1, keepdim=True)
            future_q = self.stable_net(next_states, batch_edge_index).gather(1, best_future_actions)
            target_q = rewards + self.cfg['gamma'] * future_q * (1 - dones)

        loss = F.smooth_l1_loss(current_q, target_q)
        
        self.opt.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), self.cfg['grad_clip'])
        self.opt.step()

# %%
# CELL 5: Training Execution Logic
def execute_simulation_run(env_cfg_path, hyperparams):
    save_directory = Path("project_weights") / "gat_d3qn_run" # Changed folder name
    save_directory.mkdir(parents=True, exist_ok=True)
    
    # NEW: Build the mathematical graph
    city_edges, expected_agents = build_city_graph(env_cfg_path)
    
    simulator = gym.make(id='cityflow-v0', configPath=env_cfg_path, episodeSteps=hyperparams['max_steps'])
    initial_reading = simulator.reset()
    traffic_nodes = sorted(initial_reading.keys())
    
    total_eps = hyperparams['episodes']
    hyperparams['decay_eps'] = (hyperparams['min_eps'] / hyperparams['initial_eps']) ** (1.0 / total_eps)
    
    # NEW: Pass edges into Coordinator
    coordinator = GlobalTrafficCoordinator(
        state_size=hyperparams['state_dim'],
        action_size=hyperparams['action_dim'],
        total_agents=len(traffic_nodes),
        config=hyperparams,
        base_graph_edges=city_edges 
    )
    
    performance_log = []

    # THE REST OF YOUR TRAINING LOOP REMAINS EXACTLY THE SAME!
    for episode in range(1, total_eps + 1):
        # Reset with random seed
        simulator.seed(np.random.randint(0, 999999))
        raw_state = simulator.reset()
        
        # Format State
        current_state = [np.array(raw_state[node], dtype=np.float32).flatten() for node in traffic_nodes]
        cumulative_score = 0

        for step in range(hyperparams['max_steps']):
            # Act
            action_vector = coordinator.pick_actions(current_state)
            
            # Step Simulator
            raw_next_state, raw_rewards, is_terminal, _ = simulator.step(action_vector)
            
            # Format Next State & Rewards
            next_state = [np.array(raw_next_state[node], dtype=np.float32).flatten() for node in traffic_nodes]
            reward_mapping = dict(raw_rewards)
            reward_vector = [reward_mapping[node] for node in traffic_nodes]
            
            cumulative_score += sum(reward_vector)

            # Record and Learn
            coordinator.record_and_train(current_state, action_vector, next_state, reward_vector, is_terminal)
            
            current_state = next_state
            if is_terminal:
                break

        coordinator.decay_exploration()
        performance_log.append(cumulative_score)
        
        print(f"Run {episode:04d} | Score: {cumulative_score:8.1f} | Exploration Rate: {coordinator.explore_rate:.3f}")

        # Specific Checkpointing
        if episode % hyperparams['save_interval'] == 0:
            ckpt_file = save_directory / f"d3qn_gat_{episode}.pth"
            torch.save(coordinator.policy_net.state_dict(), ckpt_file)
            print(f"--> Checkpoint secured: {ckpt_file.name}")

    # Final Save
    final_file = save_directory / "d3qn_gat.pth"
    torch.save(coordinator.policy_net.state_dict(), final_file)
    print(f"\nTraining Complete. Final model stored at {final_file}")
    
    simulator.close()
    return performance_log

# %%
# CELL 6: Configuration and Execution
config_parameters = {
    'episodes': 500,
    'max_steps': 1000,
    'state_dim': 72,
    'action_dim': 9,
    'buffer_limit': 15000, # Per agent, total buffer is 15000 * num_agents
    'batch_sz': 128,
    'update_freq': 4,
    'sync_freq': 8,
    'learning_rate': 1e-4,
    'gamma': 0.99, # Updated from 0.8 to better handle delayed traffic rewards
    'initial_eps': 1.0,
    'min_eps': 0.05,
    'grad_clip': 1.0,
    'save_interval': 250
}

# Run the pipeline
# NOTE: Ensure "../configs/Intersections_4/sample_config.json" exists in your directory
training_history = execute_simulation_run("../configs/Intersections_4/sample_config.json", config_parameters)

# Plotting the Learning Curve
plt.figure(figsize=(10, 5))
plt.plot(training_history, color='teal', linewidth=2)
plt.title("Multi-Agent Traffic Policy Convergence")
plt.xlabel("Episode")
plt.ylabel("Cumulative City Reward")
plt.grid(True, alpha=0.3)   
plt.show()
# Out:
# Run 0001 | Score: -1024024.8 | Exploration Rate: 0.994
# Run 0002 | Score: -983788.8 | Exploration Rate: 0.988
# Run 0003 | Score: -1033162.2 | Exploration Rate: 0.982
# Run 0004 | Score: -951286.8 | Exploration Rate: 0.976
# Run 0005 | Score: -934771.2 | Exploration Rate: 0.970
# Run 0006 | Score: -980028.0 | Exploration Rate: 0.965
# Run 0007 | Score: -944760.6 | Exploration Rate: 0.959
# Run 0008 | Score: -895561.2 | Exploration Rate: 0.953
# Run 0009 | Score: -887787.6 | Exploration Rate: 0.948
# Run 0010 | Score: -913259.4 | Exploration Rate: 0.942
# Run 0011 | Score: -901101.0 | Exploration Rate: 0.936
# Run 0012 | Score: -900261.6 | Exploration Rate: 0.931
# Run 0013 | Score: -923764.2 | Exploration Rate: 0.925
# Run 0014 | Score: -899228.4 | Exploration Rate: 0.920
# Run 0015 | Score: -891450.0 | Exploration Rate: 0.914
# Run 0016 | Score: -900704.4 | Exploration Rate: 0.909
# Run 0017 | Score: -841523.4 | Exploration Rate: 0.903
# Run 0018 | Score: -819819.6 | Exploration Rate: 0.898
# Run 0019 | Score: -839650.8 | Exploration Rate: 0.892
# Run 0020 | Score: -903170.4 | Exploration Rate: 0.887
# Run 0021 | Score: -845764.2 | Exploration Rate: 0.882
# Run 0022 | Score: -875268.0 | Exploration Rate: 0.877
# Run 0023 | Score: -775458.0 | Exploration Rate: 0.871
# Run 0024 | Score: -768111.0 | Exploration Rate: 0.866
# Run 0025 | Score: -840238.2 | Exploration Rate: 0.861
# Run 0026 | Score: -924481.2 | Exploration Rate: 0.856
# Run 0027 | Score: -798999.0 | Exploration Rate: 0.851
# Run 0028 | Score: -996500.4 | Exploration Rate: 0.846
# Run 0029 | Score: -823375.2 | Exploration Rate: 0.841
# Run 0030 | Score: -776960.4 | Exploration Rate: 0.835
# Run 0031 | Score: -836169.0 | Exploration Rate: 0.830
# Run 0032 | Score: -789811.8 | Exploration Rate: 0.826
# Run 0033 | Score: -912957.0 | Exploration Rate: 0.821
# Run 0034 | Score: -777142.8 | Exploration Rate: 0.816
# Run 0035 | Score: -779566.2 | Exploration Rate: 0.811
# Run 0036 | Score: -796362.0 | Exploration Rate: 0.806
# Run 0037 | Score: -912091.2 | Exploration Rate: 0.801
# Run 0038 | Score: -837731.4 | Exploration Rate: 0.796
# Run 0039 | Score: -773590.2 | Exploration Rate: 0.792
# Run 0040 | Score: -753067.2 | Exploration Rate: 0.787
# Run 0041 | Score: -746976.0 | Exploration Rate: 0.782
# Run 0042 | Score: -851008.2 | Exploration Rate: 0.778
# Run 0043 | Score: -776302.8 | Exploration Rate: 0.773
# Run 0044 | Score: -712568.4 | Exploration Rate: 0.768
# Run 0045 | Score: -808209.0 | Exploration Rate: 0.764
# Run 0046 | Score: -855581.4 | Exploration Rate: 0.759
# Run 0047 | Score: -614389.8 | Exploration Rate: 0.755
# Run 0048 | Score: -736134.6 | Exploration Rate: 0.750
# Run 0049 | Score: -914144.4 | Exploration Rate: 0.746
# Run 0050 | Score: -1006335.0 | Exploration Rate: 0.741
# Run 0051 | Score: -757278.6 | Exploration Rate: 0.737
# Run 0052 | Score: -738219.6 | Exploration Rate: 0.732
# Run 0053 | Score: -830076.0 | Exploration Rate: 0.728
# Run 0054 | Score: -636144.0 | Exploration Rate: 0.724
# Run 0055 | Score: -606835.8 | Exploration Rate: 0.719
# Run 0056 | Score: -586358.4 | Exploration Rate: 0.715
# Run 0057 | Score: -639160.2 | Exploration Rate: 0.711
# Run 0058 | Score: -572123.4 | Exploration Rate: 0.706
# Run 0059 | Score: -627706.8 | Exploration Rate: 0.702
# Run 0060 | Score: -579979.2 | Exploration Rate: 0.698
# Run 0061 | Score: -525166.2 | Exploration Rate: 0.694
# Run 0062 | Score: -705310.8 | Exploration Rate: 0.690
# Run 0063 | Score: -547594.2 | Exploration Rate: 0.686
# Run 0064 | Score: -496388.4 | Exploration Rate: 0.682
# Run 0065 | Score: -544985.4 | Exploration Rate: 0.677
# Run 0066 | Score: -519124.2 | Exploration Rate: 0.673
# Run 0067 | Score: -547145.4 | Exploration Rate: 0.669
# Run 0068 | Score: -520887.0 | Exploration Rate: 0.665
# Run 0069 | Score: -580506.6 | Exploration Rate: 0.661
# Run 0070 | Score: -565605.0 | Exploration Rate: 0.657
# Run 0071 | Score: -631559.4 | Exploration Rate: 0.654
# Run 0072 | Score: -559965.0 | Exploration Rate: 0.650
# Run 0073 | Score: -478614.6 | Exploration Rate: 0.646
# Run 0074 | Score: -503839.8 | Exploration Rate: 0.642
# Run 0075 | Score: -492690.0 | Exploration Rate: 0.638
# Run 0076 | Score: -483984.0 | Exploration Rate: 0.634
# Run 0077 | Score: -442698.6 | Exploration Rate: 0.630
# Run 0078 | Score: -487158.6 | Exploration Rate: 0.627
# Run 0079 | Score: -497002.8 | Exploration Rate: 0.623
# Run 0080 | Score: -458691.6 | Exploration Rate: 0.619
# Run 0081 | Score: -451014.0 | Exploration Rate: 0.616
# Run 0082 | Score: -464624.4 | Exploration Rate: 0.612
# Run 0083 | Score: -489126.6 | Exploration Rate: 0.608
# Run 0084 | Score: -418715.4 | Exploration Rate: 0.605
# Run 0085 | Score: -503619.0 | Exploration Rate: 0.601
# Run 0086 | Score: -460799.4 | Exploration Rate: 0.597
# Run 0087 | Score: -579070.2 | Exploration Rate: 0.594
# Run 0088 | Score: -407220.6 | Exploration Rate: 0.590
# Run 0089 | Score: -481084.2 | Exploration Rate: 0.587
# Run 0090 | Score: -498387.0 | Exploration Rate: 0.583
# Run 0091 | Score: -418947.0 | Exploration Rate: 0.580
# Run 0092 | Score: -443532.6 | Exploration Rate: 0.576
# Run 0093 | Score: -426970.2 | Exploration Rate: 0.573
# Run 0094 | Score: -446037.0 | Exploration Rate: 0.569
# Run 0095 | Score: -426339.0 | Exploration Rate: 0.566
# Run 0096 | Score: -429462.6 | Exploration Rate: 0.563
# Run 0097 | Score: -475520.4 | Exploration Rate: 0.559
# Run 0098 | Score: -435991.2 | Exploration Rate: 0.556
# Run 0099 | Score: -415555.2 | Exploration Rate: 0.553
# Run 0100 | Score: -417053.4 | Exploration Rate: 0.549
# Run 0101 | Score: -379008.6 | Exploration Rate: 0.546
# Run 0102 | Score: -405511.2 | Exploration Rate: 0.543
# Run 0103 | Score: -415988.4 | Exploration Rate: 0.539
# Run 0104 | Score: -402532.8 | Exploration Rate: 0.536
# Run 0105 | Score: -409209.6 | Exploration Rate: 0.533
# Run 0106 | Score: -381094.2 | Exploration Rate: 0.530
# Run 0107 | Score: -403312.2 | Exploration Rate: 0.527
# Run 0108 | Score: -378376.2 | Exploration Rate: 0.524
# Run 0109 | Score: -410779.2 | Exploration Rate: 0.520
# Run 0110 | Score: -457105.2 | Exploration Rate: 0.517
# Run 0111 | Score: -421935.6 | Exploration Rate: 0.514
# Run 0112 | Score: -417314.4 | Exploration Rate: 0.511
# Run 0113 | Score: -400362.0 | Exploration Rate: 0.508
# Run 0114 | Score: -382169.4 | Exploration Rate: 0.505
# Run 0115 | Score: -409059.6 | Exploration Rate: 0.502
# Run 0116 | Score: -455658.0 | Exploration Rate: 0.499
# Run 0117 | Score: -446621.4 | Exploration Rate: 0.496
# Run 0118 | Score: -369043.2 | Exploration Rate: 0.493
# Run 0119 | Score: -369822.6 | Exploration Rate: 0.490
# Run 0120 | Score: -471562.2 | Exploration Rate: 0.487
# Run 0121 | Score: -397891.2 | Exploration Rate: 0.484
# Run 0122 | Score: -404644.2 | Exploration Rate: 0.481
# Run 0123 | Score: -378036.6 | Exploration Rate: 0.479
# Run 0124 | Score: -382234.8 | Exploration Rate: 0.476
# Run 0125 | Score: -418937.4 | Exploration Rate: 0.473
# Run 0126 | Score: -427974.0 | Exploration Rate: 0.470
# Run 0127 | Score: -395353.2 | Exploration Rate: 0.467
# Run 0128 | Score: -349360.8 | Exploration Rate: 0.464
# Run 0129 | Score: -362487.6 | Exploration Rate: 0.462
# Run 0130 | Score: -373281.0 | Exploration Rate: 0.459
# Run 0131 | Score: -384533.4 | Exploration Rate: 0.456
# Run 0132 | Score: -370825.2 | Exploration Rate: 0.453
# Run 0133 | Score: -419448.6 | Exploration Rate: 0.451
# Run 0134 | Score: -382230.0 | Exploration Rate: 0.448
# Run 0135 | Score: -401774.4 | Exploration Rate: 0.445
# Run 0136 | Score: -390593.4 | Exploration Rate: 0.443
# Run 0137 | Score: -376654.8 | Exploration Rate: 0.440
# Run 0138 | Score: -403051.2 | Exploration Rate: 0.437
# Run 0139 | Score: -410168.4 | Exploration Rate: 0.435
# Run 0140 | Score: -367805.4 | Exploration Rate: 0.432
# Run 0141 | Score: -400656.6 | Exploration Rate: 0.430
# Run 0142 | Score: -390571.2 | Exploration Rate: 0.427
# Run 0143 | Score: -355724.4 | Exploration Rate: 0.425
# Run 0144 | Score: -367022.4 | Exploration Rate: 0.422
# Run 0145 | Score: -398990.4 | Exploration Rate: 0.419
# Run 0146 | Score: -370491.0 | Exploration Rate: 0.417
# Run 0147 | Score: -392527.2 | Exploration Rate: 0.414
# Run 0148 | Score: -417954.0 | Exploration Rate: 0.412
# Run 0149 | Score: -372717.0 | Exploration Rate: 0.410
# Run 0150 | Score: -420322.2 | Exploration Rate: 0.407
# Run 0151 | Score: -395184.0 | Exploration Rate: 0.405
# Run 0152 | Score: -410578.2 | Exploration Rate: 0.402
# Run 0153 | Score: -380129.4 | Exploration Rate: 0.400
# Run 0154 | Score: -380364.0 | Exploration Rate: 0.397
# Run 0155 | Score: -363678.0 | Exploration Rate: 0.395
# Run 0156 | Score: -402885.6 | Exploration Rate: 0.393
# Run 0157 | Score: -365853.6 | Exploration Rate: 0.390
# Run 0158 | Score: -362590.8 | Exploration Rate: 0.388
# Run 0159 | Score: -345135.6 | Exploration Rate: 0.386
# Run 0160 | Score: -353074.8 | Exploration Rate: 0.383
# Run 0161 | Score: -366868.2 | Exploration Rate: 0.381
# Run 0162 | Score: -359488.8 | Exploration Rate: 0.379
# Run 0163 | Score: -336528.6 | Exploration Rate: 0.377
# Run 0164 | Score: -356101.8 | Exploration Rate: 0.374
# Run 0165 | Score: -313737.6 | Exploration Rate: 0.372
# Run 0166 | Score: -361465.8 | Exploration Rate: 0.370
# Run 0167 | Score: -353357.4 | Exploration Rate: 0.368
# Run 0168 | Score: -353964.0 | Exploration Rate: 0.365
# Run 0169 | Score: -307623.6 | Exploration Rate: 0.363
# Run 0170 | Score: -383743.8 | Exploration Rate: 0.361
# Run 0171 | Score: -350554.2 | Exploration Rate: 0.359
# Run 0172 | Score: -359369.4 | Exploration Rate: 0.357
# Run 0173 | Score: -322796.4 | Exploration Rate: 0.355
# Run 0174 | Score: -349569.0 | Exploration Rate: 0.353
# Run 0175 | Score: -350772.6 | Exploration Rate: 0.350
# Run 0176 | Score: -348455.4 | Exploration Rate: 0.348
# Run 0177 | Score: -376702.8 | Exploration Rate: 0.346
# Run 0178 | Score: -381797.4 | Exploration Rate: 0.344
# Run 0179 | Score: -331705.8 | Exploration Rate: 0.342
# Run 0180 | Score: -408993.6 | Exploration Rate: 0.340
# Run 0181 | Score: -352762.2 | Exploration Rate: 0.338
# Run 0182 | Score: -346311.0 | Exploration Rate: 0.336
# Run 0183 | Score: -323421.0 | Exploration Rate: 0.334
# Run 0184 | Score: -339343.8 | Exploration Rate: 0.332
# Run 0185 | Score: -363202.2 | Exploration Rate: 0.330
# Run 0186 | Score: -359116.8 | Exploration Rate: 0.328
# Run 0187 | Score: -356400.0 | Exploration Rate: 0.326
# Run 0188 | Score: -319213.8 | Exploration Rate: 0.324
# Run 0189 | Score: -348673.8 | Exploration Rate: 0.322
# Run 0190 | Score: -365371.8 | Exploration Rate: 0.320
# Run 0191 | Score: -301061.4 | Exploration Rate: 0.318
# Run 0192 | Score: -339678.6 | Exploration Rate: 0.317
# Run 0193 | Score: -298491.6 | Exploration Rate: 0.315
# Run 0194 | Score: -328420.2 | Exploration Rate: 0.313
# Run 0195 | Score: -330337.2 | Exploration Rate: 0.311
# Run 0196 | Score: -320961.6 | Exploration Rate: 0.309
# Run 0197 | Score: -337477.8 | Exploration Rate: 0.307
# Run 0198 | Score: -369726.6 | Exploration Rate: 0.305
# Run 0199 | Score: -382140.6 | Exploration Rate: 0.304
# Run 0200 | Score: -369046.2 | Exploration Rate: 0.302
# Run 0201 | Score: -352661.4 | Exploration Rate: 0.300
# Run 0202 | Score: -317849.4 | Exploration Rate: 0.298
# Run 0203 | Score: -337039.8 | Exploration Rate: 0.296
# Run 0204 | Score: -316779.6 | Exploration Rate: 0.295
# Run 0205 | Score: -340158.6 | Exploration Rate: 0.293
# Run 0206 | Score: -333730.2 | Exploration Rate: 0.291
# Run 0207 | Score: -356705.4 | Exploration Rate: 0.289
# Run 0208 | Score: -329000.4 | Exploration Rate: 0.288
# Run 0209 | Score: -348815.4 | Exploration Rate: 0.286
# Run 0210 | Score: -334090.8 | Exploration Rate: 0.284
# Run 0211 | Score: -339565.2 | Exploration Rate: 0.282
# Run 0212 | Score: -363774.0 | Exploration Rate: 0.281
# Run 0213 | Score: -307297.8 | Exploration Rate: 0.279
# Run 0214 | Score: -326863.8 | Exploration Rate: 0.277
# Run 0215 | Score: -388461.6 | Exploration Rate: 0.276
# Run 0216 | Score: -319605.0 | Exploration Rate: 0.274
# Run 0217 | Score: -319733.4 | Exploration Rate: 0.272
# Run 0218 | Score: -314170.8 | Exploration Rate: 0.271
# Run 0219 | Score: -356637.6 | Exploration Rate: 0.269
# Run 0220 | Score: -320298.0 | Exploration Rate: 0.268
# Run 0221 | Score: -326416.2 | Exploration Rate: 0.266
# Run 0222 | Score: -292554.6 | Exploration Rate: 0.264
# Run 0223 | Score: -316026.0 | Exploration Rate: 0.263
# Run 0224 | Score: -332239.2 | Exploration Rate: 0.261
# Run 0225 | Score: -305437.2 | Exploration Rate: 0.260
# Run 0226 | Score: -295015.8 | Exploration Rate: 0.258
# Run 0227 | Score: -302557.2 | Exploration Rate: 0.257
# Run 0228 | Score: -332216.4 | Exploration Rate: 0.255
# Run 0229 | Score: -276073.2 | Exploration Rate: 0.254
# Run 0230 | Score: -310296.6 | Exploration Rate: 0.252
# Run 0231 | Score: -269022.6 | Exploration Rate: 0.251
# Run 0232 | Score: -303022.2 | Exploration Rate: 0.249
# Run 0233 | Score: -361032.6 | Exploration Rate: 0.248
# Run 0234 | Score: -302487.6 | Exploration Rate: 0.246
# Run 0235 | Score: -285387.6 | Exploration Rate: 0.245
# Run 0236 | Score: -302662.2 | Exploration Rate: 0.243
# Run 0237 | Score: -298109.4 | Exploration Rate: 0.242
# Run 0238 | Score: -289787.4 | Exploration Rate: 0.240
# Run 0239 | Score: -332457.0 | Exploration Rate: 0.239
# Run 0240 | Score: -301735.8 | Exploration Rate: 0.237
# Run 0241 | Score: -275919.6 | Exploration Rate: 0.236
# Run 0242 | Score: -328885.2 | Exploration Rate: 0.235
# Run 0243 | Score: -285603.6 | Exploration Rate: 0.233
# Run 0244 | Score: -316482.6 | Exploration Rate: 0.232
# Run 0245 | Score: -401680.2 | Exploration Rate: 0.230
# Run 0246 | Score: -461012.4 | Exploration Rate: 0.229
# Run 0247 | Score: -329464.8 | Exploration Rate: 0.228
# Run 0248 | Score: -265458.6 | Exploration Rate: 0.226
# Run 0249 | Score: -302961.0 | Exploration Rate: 0.225
# Run 0250 | Score: -295527.0 | Exploration Rate: 0.224
# --> Checkpoint secured: d3qn_gat_250.pth
# Run 0251 | Score: -300109.8 | Exploration Rate: 0.222
# Run 0252 | Score: -342110.4 | Exploration Rate: 0.221
# Run 0253 | Score: -316327.2 | Exploration Rate: 0.220
# Run 0254 | Score: -298393.8 | Exploration Rate: 0.218
# Run 0255 | Score: -319787.4 | Exploration Rate: 0.217
# Run 0256 | Score: -284427.0 | Exploration Rate: 0.216
# Run 0257 | Score: -336632.4 | Exploration Rate: 0.214
# Run 0258 | Score: -323233.8 | Exploration Rate: 0.213
# Run 0259 | Score: -313562.4 | Exploration Rate: 0.212
# Run 0260 | Score: -309697.8 | Exploration Rate: 0.211
# Run 0261 | Score: -302737.8 | Exploration Rate: 0.209
# Run 0262 | Score: -341497.2 | Exploration Rate: 0.208
# Run 0263 | Score: -281090.4 | Exploration Rate: 0.207
# Run 0264 | Score: -354576.6 | Exploration Rate: 0.206
# Run 0265 | Score: -272632.2 | Exploration Rate: 0.204
# Run 0266 | Score: -281961.6 | Exploration Rate: 0.203
# Run 0267 | Score: -305752.2 | Exploration Rate: 0.202
# Run 0268 | Score: -309723.0 | Exploration Rate: 0.201
# Run 0269 | Score: -333104.4 | Exploration Rate: 0.200
# Run 0270 | Score: -306241.2 | Exploration Rate: 0.198
# Run 0271 | Score: -286470.6 | Exploration Rate: 0.197
# Run 0272 | Score: -296905.8 | Exploration Rate: 0.196
# Run 0273 | Score: -267540.0 | Exploration Rate: 0.195
# Run 0274 | Score: -255999.0 | Exploration Rate: 0.194
# Run 0275 | Score: -315085.2 | Exploration Rate: 0.193
# Run 0276 | Score: -289054.2 | Exploration Rate: 0.191
# Run 0277 | Score: -338637.6 | Exploration Rate: 0.190
# Run 0278 | Score: -282172.2 | Exploration Rate: 0.189
# Run 0279 | Score: -275421.6 | Exploration Rate: 0.188
# Run 0280 | Score: -303963.0 | Exploration Rate: 0.187
# Run 0281 | Score: -314049.0 | Exploration Rate: 0.186
# Run 0282 | Score: -280630.2 | Exploration Rate: 0.185
# Run 0283 | Score: -304429.8 | Exploration Rate: 0.183
# Run 0284 | Score: -281672.4 | Exploration Rate: 0.182
# Run 0285 | Score: -330830.4 | Exploration Rate: 0.181
# Run 0286 | Score: -282022.8 | Exploration Rate: 0.180
# Run 0287 | Score: -256383.0 | Exploration Rate: 0.179
# Run 0288 | Score: -277552.8 | Exploration Rate: 0.178
# Run 0289 | Score: -248748.0 | Exploration Rate: 0.177
# Run 0290 | Score: -271574.4 | Exploration Rate: 0.176
# Run 0291 | Score: -277860.6 | Exploration Rate: 0.175
# Run 0292 | Score: -262429.8 | Exploration Rate: 0.174
# Run 0293 | Score: -291683.4 | Exploration Rate: 0.173
# Run 0294 | Score: -255947.4 | Exploration Rate: 0.172
# Run 0295 | Score: -302376.0 | Exploration Rate: 0.171
# Run 0296 | Score: -294868.8 | Exploration Rate: 0.170
# Run 0297 | Score: -266926.8 | Exploration Rate: 0.169
# Run 0298 | Score: -270630.0 | Exploration Rate: 0.168
# Run 0299 | Score: -247326.0 | Exploration Rate: 0.167
# Run 0300 | Score: -254068.8 | Exploration Rate: 0.166
# Run 0301 | Score: -291012.0 | Exploration Rate: 0.165
# Run 0302 | Score: -344122.2 | Exploration Rate: 0.164
# Run 0303 | Score: -308164.8 | Exploration Rate: 0.163
# Run 0304 | Score: -254899.2 | Exploration Rate: 0.162
# Run 0305 | Score: -270865.2 | Exploration Rate: 0.161
# Run 0306 | Score: -267684.6 | Exploration Rate: 0.160
# Run 0307 | Score: -315865.2 | Exploration Rate: 0.159
# Run 0308 | Score: -340084.2 | Exploration Rate: 0.158
# Run 0309 | Score: -272666.4 | Exploration Rate: 0.157
# Run 0310 | Score: -283178.4 | Exploration Rate: 0.156
# Run 0311 | Score: -310401.6 | Exploration Rate: 0.155
# Run 0312 | Score: -265707.6 | Exploration Rate: 0.154
# Run 0313 | Score: -256986.0 | Exploration Rate: 0.153
# Run 0314 | Score: -261735.0 | Exploration Rate: 0.152
# Run 0315 | Score: -271754.4 | Exploration Rate: 0.151
# Run 0316 | Score: -283639.2 | Exploration Rate: 0.151
# Run 0317 | Score: -259872.6 | Exploration Rate: 0.150
# Run 0318 | Score: -260465.4 | Exploration Rate: 0.149
# Run 0319 | Score: -255404.4 | Exploration Rate: 0.148
# Run 0320 | Score: -230881.2 | Exploration Rate: 0.147
# Run 0321 | Score: -257104.2 | Exploration Rate: 0.146
# Run 0322 | Score: -288756.6 | Exploration Rate: 0.145
# Run 0323 | Score: -286709.4 | Exploration Rate: 0.144
# Run 0324 | Score: -279864.6 | Exploration Rate: 0.144
# Run 0325 | Score: -269253.0 | Exploration Rate: 0.143
# Run 0326 | Score: -280647.6 | Exploration Rate: 0.142
# Run 0327 | Score: -246212.4 | Exploration Rate: 0.141
# Run 0328 | Score: -239988.0 | Exploration Rate: 0.140
# Run 0329 | Score: -257461.2 | Exploration Rate: 0.139
# Run 0330 | Score: -260028.0 | Exploration Rate: 0.138
# Run 0331 | Score: -279994.8 | Exploration Rate: 0.138
# Run 0332 | Score: -265198.2 | Exploration Rate: 0.137
# Run 0333 | Score: -268893.0 | Exploration Rate: 0.136
# Run 0334 | Score: -284569.2 | Exploration Rate: 0.135
# Run 0335 | Score: -273600.0 | Exploration Rate: 0.134
# Run 0336 | Score: -297066.6 | Exploration Rate: 0.134
# Run 0337 | Score: -309798.6 | Exploration Rate: 0.133
# Run 0338 | Score: -305141.4 | Exploration Rate: 0.132
# Run 0339 | Score: -290677.2 | Exploration Rate: 0.131
# Run 0340 | Score: -282886.2 | Exploration Rate: 0.130
# Run 0341 | Score: -282796.2 | Exploration Rate: 0.130
# Run 0342 | Score: -295335.0 | Exploration Rate: 0.129
# Run 0343 | Score: -309624.6 | Exploration Rate: 0.128
# Run 0344 | Score: -294970.2 | Exploration Rate: 0.127
# Run 0345 | Score: -326007.6 | Exploration Rate: 0.127
# Run 0346 | Score: -309636.0 | Exploration Rate: 0.126
# Run 0347 | Score: -297324.6 | Exploration Rate: 0.125
# Run 0348 | Score: -306168.6 | Exploration Rate: 0.124
# Run 0349 | Score: -303515.4 | Exploration Rate: 0.124
# Run 0350 | Score: -310526.4 | Exploration Rate: 0.123
# Run 0351 | Score: -277678.2 | Exploration Rate: 0.122
# Run 0352 | Score: -1232223.6 | Exploration Rate: 0.121
# Run 0353 | Score: -353131.2 | Exploration Rate: 0.121
# Run 0354 | Score: -329283.6 | Exploration Rate: 0.120
# Run 0355 | Score: -343320.6 | Exploration Rate: 0.119
# Run 0356 | Score: -459090.6 | Exploration Rate: 0.118
# Run 0357 | Score: -331815.0 | Exploration Rate: 0.118
# Run 0358 | Score: -342238.8 | Exploration Rate: 0.117
# Run 0359 | Score: -315845.4 | Exploration Rate: 0.116
# Run 0360 | Score: -393198.6 | Exploration Rate: 0.116
# Run 0361 | Score: -353707.2 | Exploration Rate: 0.115
# Run 0362 | Score: -285327.0 | Exploration Rate: 0.114
# Run 0363 | Score: -286719.6 | Exploration Rate: 0.114
# Run 0364 | Score: -237939.6 | Exploration Rate: 0.113
# Run 0365 | Score: -271310.4 | Exploration Rate: 0.112
# Run 0366 | Score: -278482.2 | Exploration Rate: 0.112
# Run 0367 | Score: -247241.4 | Exploration Rate: 0.111
# Run 0368 | Score: -261924.0 | Exploration Rate: 0.110
# Run 0369 | Score: -251511.0 | Exploration Rate: 0.110
# Run 0370 | Score: -282648.6 | Exploration Rate: 0.109
# Run 0371 | Score: -280356.0 | Exploration Rate: 0.108
# Run 0372 | Score: -290514.6 | Exploration Rate: 0.108
# Run 0373 | Score: -248724.0 | Exploration Rate: 0.107
# Run 0374 | Score: -271012.2 | Exploration Rate: 0.106
# Run 0375 | Score: -241906.8 | Exploration Rate: 0.106
# Run 0376 | Score: -287103.0 | Exploration Rate: 0.105
# Run 0377 | Score: -402135.6 | Exploration Rate: 0.104
# Run 0378 | Score: -281277.6 | Exploration Rate: 0.104
# Run 0379 | Score: -243741.0 | Exploration Rate: 0.103
# Run 0380 | Score: -367971.6 | Exploration Rate: 0.103
# Run 0381 | Score: -273930.0 | Exploration Rate: 0.102
# Run 0382 | Score: -324813.0 | Exploration Rate: 0.101
# Run 0383 | Score: -440725.8 | Exploration Rate: 0.101
# Run 0384 | Score: -276459.6 | Exploration Rate: 0.100
# Run 0385 | Score: -237996.0 | Exploration Rate: 0.100
# Run 0386 | Score: -258098.4 | Exploration Rate: 0.099
# Run 0387 | Score: -907807.8 | Exploration Rate: 0.098
# Run 0388 | Score: -291009.0 | Exploration Rate: 0.098
# Run 0389 | Score: -272353.8 | Exploration Rate: 0.097
# Run 0390 | Score: -318451.8 | Exploration Rate: 0.097
# Run 0391 | Score: -262264.8 | Exploration Rate: 0.096
# Run 0392 | Score: -241108.2 | Exploration Rate: 0.095
# Run 0393 | Score: -307744.8 | Exploration Rate: 0.095
# Run 0394 | Score: -270110.4 | Exploration Rate: 0.094
# Run 0395 | Score: -286993.2 | Exploration Rate: 0.094
# Run 0396 | Score: -279645.6 | Exploration Rate: 0.093
# Run 0397 | Score: -356698.8 | Exploration Rate: 0.093
# Run 0398 | Score: -297613.8 | Exploration Rate: 0.092
# Run 0399 | Score: -234315.0 | Exploration Rate: 0.092
# Run 0400 | Score: -285072.6 | Exploration Rate: 0.091
# Run 0401 | Score: -268800.0 | Exploration Rate: 0.090
# Run 0402 | Score: -268708.2 | Exploration Rate: 0.090
# Run 0403 | Score: -291126.6 | Exploration Rate: 0.089
# Run 0404 | Score: -266778.0 | Exploration Rate: 0.089
# Run 0405 | Score: -320695.8 | Exploration Rate: 0.088
# Run 0406 | Score: -333235.8 | Exploration Rate: 0.088
# Run 0407 | Score: -314009.4 | Exploration Rate: 0.087
# Run 0408 | Score: -302259.6 | Exploration Rate: 0.087
# Run 0409 | Score: -283393.8 | Exploration Rate: 0.086
# Run 0410 | Score: -277770.0 | Exploration Rate: 0.086
# Run 0411 | Score: -275185.8 | Exploration Rate: 0.085
# Run 0412 | Score: -235829.4 | Exploration Rate: 0.085
# Run 0413 | Score: -249654.0 | Exploration Rate: 0.084
# Run 0414 | Score: -251548.2 | Exploration Rate: 0.084
# Run 0415 | Score: -278133.6 | Exploration Rate: 0.083
# Run 0416 | Score: -255193.8 | Exploration Rate: 0.083
# Run 0417 | Score: -266908.8 | Exploration Rate: 0.082
# Run 0418 | Score: -275459.4 | Exploration Rate: 0.082
# Run 0419 | Score: -264329.4 | Exploration Rate: 0.081
# Run 0420 | Score: -272423.4 | Exploration Rate: 0.081
# Run 0421 | Score: -266022.0 | Exploration Rate: 0.080
# Run 0422 | Score: -275153.4 | Exploration Rate: 0.080
# Run 0423 | Score: -231851.4 | Exploration Rate: 0.079
# Run 0424 | Score: -225135.0 | Exploration Rate: 0.079
# Run 0425 | Score: -260065.2 | Exploration Rate: 0.078
# Run 0426 | Score: -263228.4 | Exploration Rate: 0.078
# Run 0427 | Score: -256969.2 | Exploration Rate: 0.077
# Run 0428 | Score: -256602.0 | Exploration Rate: 0.077
# Run 0429 | Score: -257531.4 | Exploration Rate: 0.077
# Run 0430 | Score: -280704.0 | Exploration Rate: 0.076
# Run 0431 | Score: -242095.8 | Exploration Rate: 0.076
# Run 0432 | Score: -298650.6 | Exploration Rate: 0.075
# Run 0433 | Score: -267468.0 | Exploration Rate: 0.075
# Run 0434 | Score: -284010.0 | Exploration Rate: 0.074
# Run 0435 | Score: -263232.0 | Exploration Rate: 0.074
# Run 0436 | Score: -286163.4 | Exploration Rate: 0.073
# Run 0437 | Score: -262753.8 | Exploration Rate: 0.073
# Run 0438 | Score: -258107.4 | Exploration Rate: 0.072
# Run 0439 | Score: -282226.8 | Exploration Rate: 0.072
# Run 0440 | Score: -272116.2 | Exploration Rate: 0.072
# Run 0441 | Score: -281041.8 | Exploration Rate: 0.071
# Run 0442 | Score: -253950.0 | Exploration Rate: 0.071
# Run 0443 | Score: -209370.6 | Exploration Rate: 0.070
# Run 0444 | Score: -257594.4 | Exploration Rate: 0.070
# Run 0445 | Score: -287133.6 | Exploration Rate: 0.070
# Run 0446 | Score: -276151.2 | Exploration Rate: 0.069
# Run 0447 | Score: -249246.0 | Exploration Rate: 0.069
# Run 0448 | Score: -269932.8 | Exploration Rate: 0.068
# Run 0449 | Score: -245295.0 | Exploration Rate: 0.068
# Run 0450 | Score: -309405.0 | Exploration Rate: 0.067
# Run 0451 | Score: -301541.4 | Exploration Rate: 0.067
# Run 0452 | Score: -254368.8 | Exploration Rate: 0.067
# Run 0453 | Score: -298128.6 | Exploration Rate: 0.066
# Run 0454 | Score: -253507.8 | Exploration Rate: 0.066
# Run 0455 | Score: -296575.2 | Exploration Rate: 0.065
# Run 0456 | Score: -243429.0 | Exploration Rate: 0.065
# Run 0457 | Score: -353440.2 | Exploration Rate: 0.065
# Run 0458 | Score: -282824.4 | Exploration Rate: 0.064
# Run 0459 | Score: -287722.8 | Exploration Rate: 0.064
# Run 0460 | Score: -238533.0 | Exploration Rate: 0.064
# Run 0461 | Score: -244117.8 | Exploration Rate: 0.063
# Run 0462 | Score: -237511.8 | Exploration Rate: 0.063
# Run 0463 | Score: -250662.6 | Exploration Rate: 0.062
# Run 0464 | Score: -250744.8 | Exploration Rate: 0.062
# Run 0465 | Score: -238592.4 | Exploration Rate: 0.062
# Run 0466 | Score: -306145.8 | Exploration Rate: 0.061
# Run 0467 | Score: -279004.2 | Exploration Rate: 0.061
# Run 0468 | Score: -286735.8 | Exploration Rate: 0.061
# Run 0469 | Score: -231482.4 | Exploration Rate: 0.060
# Run 0470 | Score: -264649.8 | Exploration Rate: 0.060
# Run 0471 | Score: -301281.6 | Exploration Rate: 0.059
# Run 0472 | Score: -354459.6 | Exploration Rate: 0.059
# Run 0473 | Score: -277996.8 | Exploration Rate: 0.059
# Run 0474 | Score: -261034.8 | Exploration Rate: 0.058
# Run 0475 | Score: -246031.8 | Exploration Rate: 0.058
# Run 0476 | Score: -282720.0 | Exploration Rate: 0.058
# Run 0477 | Score: -294946.8 | Exploration Rate: 0.057
# Run 0478 | Score: -291861.6 | Exploration Rate: 0.057
# Run 0479 | Score: -264352.2 | Exploration Rate: 0.057
# Run 0480 | Score: -242052.0 | Exploration Rate: 0.056
# Run 0481 | Score: -256605.6 | Exploration Rate: 0.056
# Run 0482 | Score: -211437.6 | Exploration Rate: 0.056
# Run 0483 | Score: -222784.2 | Exploration Rate: 0.055
# Run 0484 | Score: -218683.8 | Exploration Rate: 0.055
# Run 0485 | Score: -344773.2 | Exploration Rate: 0.055
# Run 0486 | Score: -278416.2 | Exploration Rate: 0.054
# Run 0487 | Score: -251611.8 | Exploration Rate: 0.054
# Run 0488 | Score: -261016.2 | Exploration Rate: 0.054
# Run 0489 | Score: -225820.2 | Exploration Rate: 0.053
# Run 0490 | Score: -241483.8 | Exploration Rate: 0.053
# Run 0491 | Score: -234410.4 | Exploration Rate: 0.053
# Run 0492 | Score: -444270.6 | Exploration Rate: 0.052
# Run 0493 | Score: -402615.0 | Exploration Rate: 0.052
# Run 0494 | Score: -336106.2 | Exploration Rate: 0.052
# Run 0495 | Score: -279354.6 | Exploration Rate: 0.052
# Run 0496 | Score: -689526.0 | Exploration Rate: 0.051
# Run 0497 | Score: -246719.4 | Exploration Rate: 0.051
# Run 0498 | Score: -289797.6 | Exploration Rate: 0.051
# Run 0499 | Score: -355989.6 | Exploration Rate: 0.050
# Run 0500 | Score: -307024.2 | Exploration Rate: 0.050
# --> Checkpoint secured: d3qn_gat_500.pth
#
# Training Complete. Final model stored at project_weights/gat_d3qn_run/d3qn_gat.pth
