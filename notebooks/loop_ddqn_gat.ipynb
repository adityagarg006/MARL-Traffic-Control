# %%
# CELL 1: Imports and Environment Setup
import os
import random
import json
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# New Graph Imports
from torch_geometric.nn import GATConv
from torch_geometric.utils import add_self_loops

import gym
import cityflow
import gym_cityflow

hardware_device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Active Compute Device: {hardware_device}")
# Out:
# Active Compute Device: cuda
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
# CELL 2: Graph Architecture and Environment Parsing

def build_city_graph(config_path):
    """Parses the roadnet JSON to build the mathematical graph (edge_index) of intersections."""
    cfg = json.load(open(config_path, "r"))
    roadnet_path = os.path.join(cfg["dir"], cfg["roadnetFile"])
    roadnet = json.load(open(roadnet_path, "r"))

    # Find valid intersections
    valid_nodes = sorted([node["id"] for node in roadnet["intersections"] if not node.get("virtual", False)])
    node_to_index = {node: idx for idx, node in enumerate(valid_nodes)}

    # Map the roads (edges)
    edge_list = []
    for road in roadnet["roads"]:
        start_node = road.get("startIntersection")
        end_node = road.get("endIntersection")
        if start_node in node_to_index and end_node in node_to_index:
            u, v = node_to_index[start_node], node_to_index[end_node]
            edge_list.append([u, v])
            edge_list.append([v, u]) # Bidirectional traffic

    # Convert to PyTorch tensor and add self-loops (so agents consider their own traffic)
    tensor_edges = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
    tensor_edges, _ = add_self_loops(tensor_edges, num_nodes=len(valid_nodes))
    
    return tensor_edges, len(valid_nodes)


class AttentionGraphTrafficBrain(nn.Module):
    """GAT-Dueling Architecture: Agents share info before calculating Value/Advantage."""
    def __init__(self, features_in, num_actions, shared_dims=[64, 64], split_dim=32, heads=4):
        super(AttentionGraphTrafficBrain, self).__init__()
        
        # 1. Graph Attention Layers (The Trunk)
        self.gat_layer_1 = GATConv(features_in, shared_dims[0], heads=heads, concat=True)
        self.gat_layer_2 = GATConv(shared_dims[0] * heads, shared_dims[1], heads=1, concat=False)
        
        # 2. Value Stream [V(s)]
        self.value_head = nn.Sequential(
            nn.Linear(shared_dims[1], split_dim),
            nn.LayerNorm(split_dim),
            nn.ReLU(inplace=True),
            nn.Linear(split_dim, 1)
        )
        
        # 3. Advantage Stream [A(s, a)]
        self.advantage_head = nn.Sequential(
            nn.Linear(shared_dims[1], split_dim),
            nn.LayerNorm(split_dim),
            nn.ReLU(inplace=True),
            nn.Linear(split_dim, num_actions)
        )

    def forward(self, x, edge_idx):
        # Route traffic data through the graph network
        hidden = F.elu(self.gat_layer_1(x, edge_idx))
        hidden = F.elu(self.gat_layer_2(hidden, edge_idx))
        
        # Calculate Dueling Q-Values
        state_value = self.value_head(hidden)
        action_advantages = self.advantage_head(hidden)
        
        q_predictions = state_value + (action_advantages - action_advantages.mean(dim=1, keepdim=True))
        return q_predictions


class RunningRewardScaler:
    # KEEP YOUR EXISTING REWARD SCALER CODE HERE (No changes needed)
    def __init__(self, decay_rate=0.001, epsilon=1e-8):
        self.running_mean = 0.0
        self.running_variance = 1.0
        self.decay_rate = decay_rate
        self.epsilon = epsilon

    def scale(self, reward_array):
        current_mean = np.mean(reward_array)
        current_var = np.var(reward_array)
        self.running_mean += self.decay_rate * (current_mean - self.running_mean)
        self.running_variance += self.decay_rate * (current_var - self.running_variance)
        return (reward_array - self.running_mean) / (np.sqrt(self.running_variance) + self.epsilon)

# %%
# CELL 3: Graph-Aware Experience Replay
class GraphExperienceMemory:
    """Stores FULL graphs (all agents simultaneously) so GAT can route messages."""
    def __init__(self, max_capacity, num_agents, feature_dim):
        self.capacity = max_capacity
        self.num_agents = num_agents
        self.ptr = 0
        self.current_count = 0
        
        # Note the extra dimension to preserve the 16-agent graph structure
        self.s_mem = np.zeros((max_capacity, num_agents, feature_dim), dtype=np.float32)
        self.s_next_mem = np.zeros((max_capacity, num_agents, feature_dim), dtype=np.float32)
        self.a_mem = np.zeros((max_capacity, num_agents), dtype=np.int64)
        self.r_mem = np.zeros((max_capacity, num_agents), dtype=np.float32)
        self.done_mem = np.zeros(max_capacity, dtype=np.float32)

    def add_graph_transition(self, states, actions, next_states, rewards, done_flag):
        # Ingests the entire city state as a single interconnected snapshot
        self.s_mem[self.ptr] = states
        self.a_mem[self.ptr] = actions
        self.s_next_mem[self.ptr] = next_states
        self.r_mem[self.ptr] = rewards
        self.done_mem[self.ptr] = float(done_flag)
        
        self.ptr = (self.ptr + 1) % self.capacity
        self.current_count = min(self.current_count + 1, self.capacity)

    def draw_batch(self, sample_size):
        indices = np.random.randint(0, self.current_count, size=sample_size)
        return (
            self.s_mem[indices],
            self.a_mem[indices],
            self.r_mem[indices],
            self.s_next_mem[indices],
            self.done_mem[indices]
        )

    def __len__(self):
        return self.current_count

# %%
# CELL 4: Central Multi-Agent Graph Coordinator
class GlobalTrafficCoordinator:
    def __init__(self, state_size, action_size, total_agents, config, base_graph_edges):
        self.action_size = action_size
        self.cfg = config
        self.total_agents = total_agents
        self.base_graph_edges = base_graph_edges.to(hardware_device)
        
        self.explore_rate = config['initial_eps']
        self.explore_floor = config['min_eps']
        self.explore_decay = config['decay_eps']
        
        self.reward_processor = RunningRewardScaler()
        # Initialize the new Graph-Aware Memory
        self.memory = GraphExperienceMemory(config['buffer_limit'], total_agents, state_size)
        
        # Initialize Graph Networks
        self.policy_net = AttentionGraphTrafficBrain(state_size, action_size).to(hardware_device)
        self.stable_net = AttentionGraphTrafficBrain(state_size, action_size).to(hardware_device)
        self.stable_net.load_state_dict(self.policy_net.state_dict())
        self.stable_net.eval()
        
        self.opt = optim.Adam(self.policy_net.parameters(), lr=config['learning_rate'])
        self.interaction_steps = 0

    def pick_actions(self, observations):
        state_t = torch.tensor(np.array(observations), dtype=torch.float32, device=hardware_device)
        with torch.no_grad():
            predictions = self.policy_net(state_t, self.base_graph_edges)
            
        chosen_actions = []
        for i in range(self.total_agents):
            if random.random() < self.explore_rate:
                chosen_actions.append(random.randrange(self.action_size))
            else:
                chosen_actions.append(predictions[i].argmax().item())
        return chosen_actions

    def record_and_train(self, s, a, s_next, r, is_done):
        r_array = np.array(r, dtype=np.float32)
        scaled_r = self.reward_processor.scale(r_array)
        
        # Pass the entire 16-agent lists at once
        self.memory.add_graph_transition(s, a, s_next, scaled_r, is_done)
        
        self.interaction_steps += 1
        if len(self.memory) >= self.cfg['batch_sz'] and self.interaction_steps % self.cfg['update_freq'] == 0:
            self._optimize_weights()
            
        if self.interaction_steps % self.cfg['sync_freq'] == 0:
            self.stable_net.load_state_dict(self.policy_net.state_dict())

    def decay_exploration(self):
        self.explore_rate = max(self.explore_floor, self.explore_rate * self.explore_decay)

    def _build_batch_edges(self, batch_sz):
        """Fixes PyG batching by tiling the graph edges across the batch dimension."""
        num_edges = self.base_graph_edges.shape[1]
        batched_edges = self.base_graph_edges.repeat(1, batch_sz)
        offsets = torch.arange(batch_sz, device=hardware_device).repeat_interleave(num_edges) * self.total_agents
        return batched_edges + offsets

    def _optimize_weights(self):
        s_b, a_b, r_b, s_next_b, done_b = self.memory.draw_batch(self.cfg['batch_sz'])
        batch_sz = s_b.shape[0]
        
        # Flatten the graphs sequentially for PyTorch Geometric (Batch Size * 16 Agents)
        states = torch.FloatTensor(s_b.reshape(-1, self.cfg['state_dim'])).to(hardware_device)
        next_states = torch.FloatTensor(s_next_b.reshape(-1, self.cfg['state_dim'])).to(hardware_device)
        actions = torch.LongTensor(a_b.reshape(-1, 1)).to(hardware_device)
        rewards = torch.FloatTensor(r_b.reshape(-1, 1)).to(hardware_device)
        
        # Dones apply to the whole graph, so we repeat the flag for all 16 agents
        repeated_dones = np.repeat(done_b, self.total_agents)
        dones = torch.FloatTensor(repeated_dones.reshape(-1, 1)).to(hardware_device)

        # Generate block-diagonal edges for the batch
        batch_edge_index = self._build_batch_edges(batch_sz)

        # Double DQN + GAT Target Calculation
        current_q = self.policy_net(states, batch_edge_index).gather(1, actions)
        with torch.no_grad():
            best_future_actions = self.policy_net(next_states, batch_edge_index).argmax(dim=1, keepdim=True)
            future_q = self.stable_net(next_states, batch_edge_index).gather(1, best_future_actions)
            target_q = rewards + self.cfg['gamma'] * future_q * (1 - dones)

        loss = F.smooth_l1_loss(current_q, target_q)
        
        self.opt.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), self.cfg['grad_clip'])
        self.opt.step()

# %%
# CELL 5: Training Execution Logic
def execute_simulation_run(env_cfg_path, hyperparams):
    save_directory = Path("project_weights") / "gat_d3qn_run" # Changed folder name
    save_directory.mkdir(parents=True, exist_ok=True)
    
    # NEW: Build the mathematical graph
    city_edges, expected_agents = build_city_graph(env_cfg_path)
    
    simulator = gym.make(id='cityflow-v0', configPath=env_cfg_path, episodeSteps=hyperparams['max_steps'])
    initial_reading = simulator.reset()
    traffic_nodes = sorted(initial_reading.keys())
    
    total_eps = hyperparams['episodes']
    hyperparams['decay_eps'] = (hyperparams['min_eps'] / hyperparams['initial_eps']) ** (1.0 / total_eps)
    
    # NEW: Pass edges into Coordinator
    coordinator = GlobalTrafficCoordinator(
        state_size=hyperparams['state_dim'],
        action_size=hyperparams['action_dim'],
        total_agents=len(traffic_nodes),
        config=hyperparams,
        base_graph_edges=city_edges 
    )
    
    performance_log = []

    # THE REST OF YOUR TRAINING LOOP REMAINS EXACTLY THE SAME!
    for episode in range(1, total_eps + 1):
        # Reset with random seed
        simulator.seed(np.random.randint(0, 999999))
        raw_state = simulator.reset()
        
        # Format State
        current_state = [np.array(raw_state[node], dtype=np.float32).flatten() for node in traffic_nodes]
        cumulative_score = 0

        for step in range(hyperparams['max_steps']):
            # Act
            action_vector = coordinator.pick_actions(current_state)
            
            # Step Simulator
            raw_next_state, raw_rewards, is_terminal, _ = simulator.step(action_vector)
            
            # Format Next State & Rewards
            next_state = [np.array(raw_next_state[node], dtype=np.float32).flatten() for node in traffic_nodes]
            reward_mapping = dict(raw_rewards)
            reward_vector = [reward_mapping[node] for node in traffic_nodes]
            
            cumulative_score += sum(reward_vector)

            # Record and Learn
            coordinator.record_and_train(current_state, action_vector, next_state, reward_vector, is_terminal)
            
            current_state = next_state
            if is_terminal:
                break

        coordinator.decay_exploration()
        performance_log.append(cumulative_score)
        
        print(f"Run {episode:04d} | Score: {cumulative_score:8.1f} | Exploration Rate: {coordinator.explore_rate:.3f}")

        # Specific Checkpointing
        if episode % hyperparams['save_interval'] == 0:
            ckpt_file = save_directory / f"d3qn_gat_{episode}.pth"
            torch.save(coordinator.policy_net.state_dict(), ckpt_file)
            print(f"--> Checkpoint secured: {ckpt_file.name}")

    # Final Save
    final_file = save_directory / "loop_d3qn_gat.pth"
    torch.save(coordinator.policy_net.state_dict(), final_file)
    print(f"\nTraining Complete. Final model stored at {final_file}")
    
    simulator.close()
    return performance_log

# %%
# CELL 6: Configuration and Execution
config_parameters = {
    'episodes': 500,
    'max_steps': 1000,
    'state_dim': 72,
    'action_dim': 9,
    'buffer_limit': 15000, # Per agent, total buffer is 15000 * num_agents
    'batch_sz': 128,
    'update_freq': 4,
    'sync_freq': 8,
    'learning_rate': 1e-4,
    'gamma': 0.99, # Updated from 0.8 to better handle delayed traffic rewards
    'initial_eps': 1.0,
    'min_eps': 0.05,
    'grad_clip': 1.0,
    'save_interval': 250
}

# Run the pipeline
# NOTE: Ensure "../configs/Intersections_4/sample_config.json" exists in your directory
training_history = execute_simulation_run("../configs/Intersections_4/sample_config.json", config_parameters)

# Plotting the Learning Curve
plt.figure(figsize=(10, 5))
plt.plot(training_history, color='teal', linewidth=2)
plt.title("Multi-Agent Traffic Policy Convergence")
plt.xlabel("Episode")
plt.ylabel("Cumulative City Reward")
plt.grid(True, alpha=0.3)   
plt.show()
# Out:
# Run 0001 | Score: -974593.2 | Exploration Rate: 0.994
# Run 0002 | Score: -969221.4 | Exploration Rate: 0.988
# Run 0003 | Score: -973758.6 | Exploration Rate: 0.982
# Run 0004 | Score: -930882.6 | Exploration Rate: 0.976
# Run 0005 | Score: -963498.0 | Exploration Rate: 0.970
# Run 0006 | Score: -1005028.8 | Exploration Rate: 0.965
# Run 0007 | Score: -931534.2 | Exploration Rate: 0.959
# Run 0008 | Score: -895197.6 | Exploration Rate: 0.953
# Run 0009 | Score: -936976.8 | Exploration Rate: 0.948
# Run 0010 | Score: -921987.0 | Exploration Rate: 0.942
# Run 0011 | Score: -861027.6 | Exploration Rate: 0.936
# Run 0012 | Score: -918564.0 | Exploration Rate: 0.931
# Run 0013 | Score: -975846.0 | Exploration Rate: 0.925
# Run 0014 | Score: -878312.4 | Exploration Rate: 0.920
# Run 0015 | Score: -965186.4 | Exploration Rate: 0.914
# Run 0016 | Score: -910506.0 | Exploration Rate: 0.909
# Run 0017 | Score: -935590.8 | Exploration Rate: 0.903
# Run 0018 | Score: -890640.6 | Exploration Rate: 0.898
# Run 0019 | Score: -853732.8 | Exploration Rate: 0.892
# Run 0020 | Score: -955544.4 | Exploration Rate: 0.887
# Run 0021 | Score: -880730.4 | Exploration Rate: 0.882
# Run 0022 | Score: -799293.0 | Exploration Rate: 0.877
# Run 0023 | Score: -893730.6 | Exploration Rate: 0.871
# Run 0024 | Score: -954992.4 | Exploration Rate: 0.866
# Run 0025 | Score: -913327.2 | Exploration Rate: 0.861
# Run 0026 | Score: -808857.6 | Exploration Rate: 0.856
# Run 0027 | Score: -863302.8 | Exploration Rate: 0.851
# Run 0028 | Score: -934905.0 | Exploration Rate: 0.846
# Run 0029 | Score: -931993.2 | Exploration Rate: 0.841
# Run 0030 | Score: -844275.0 | Exploration Rate: 0.835
# Run 0031 | Score: -958398.6 | Exploration Rate: 0.830
# Run 0032 | Score: -878268.0 | Exploration Rate: 0.826
# Run 0033 | Score: -830985.0 | Exploration Rate: 0.821
# Run 0034 | Score: -932295.6 | Exploration Rate: 0.816
# Run 0035 | Score: -855605.4 | Exploration Rate: 0.811
# Run 0036 | Score: -805248.6 | Exploration Rate: 0.806
# Run 0037 | Score: -880044.0 | Exploration Rate: 0.801
# Run 0038 | Score: -905124.6 | Exploration Rate: 0.796
# Run 0039 | Score: -882112.8 | Exploration Rate: 0.792
# Run 0040 | Score: -786456.0 | Exploration Rate: 0.787
# Run 0041 | Score: -870649.2 | Exploration Rate: 0.782
# Run 0042 | Score: -786280.2 | Exploration Rate: 0.778
# Run 0043 | Score: -925696.8 | Exploration Rate: 0.773
# Run 0044 | Score: -960819.0 | Exploration Rate: 0.768
# Run 0045 | Score: -931612.8 | Exploration Rate: 0.764
# Run 0046 | Score: -864419.4 | Exploration Rate: 0.759
# Run 0047 | Score: -1011692.4 | Exploration Rate: 0.755
# Run 0048 | Score: -992469.0 | Exploration Rate: 0.750
# Run 0049 | Score: -769134.6 | Exploration Rate: 0.746
# Run 0050 | Score: -817071.6 | Exploration Rate: 0.741
# Run 0051 | Score: -908520.0 | Exploration Rate: 0.737
# Run 0052 | Score: -860056.2 | Exploration Rate: 0.732
# Run 0053 | Score: -766053.6 | Exploration Rate: 0.728
# Run 0054 | Score: -847345.2 | Exploration Rate: 0.724
# Run 0055 | Score: -734595.6 | Exploration Rate: 0.719
# Run 0056 | Score: -773958.0 | Exploration Rate: 0.715
# Run 0057 | Score: -832734.0 | Exploration Rate: 0.711
# Run 0058 | Score: -702351.6 | Exploration Rate: 0.706
# Run 0059 | Score: -800453.4 | Exploration Rate: 0.702
# Run 0060 | Score: -746971.2 | Exploration Rate: 0.698
# Run 0061 | Score: -974939.4 | Exploration Rate: 0.694
# Run 0062 | Score: -604856.4 | Exploration Rate: 0.690
# Run 0063 | Score: -705950.4 | Exploration Rate: 0.686
# Run 0064 | Score: -791992.8 | Exploration Rate: 0.682
# Run 0065 | Score: -673876.2 | Exploration Rate: 0.677
# Run 0066 | Score: -643863.6 | Exploration Rate: 0.673
# Run 0067 | Score: -662518.2 | Exploration Rate: 0.669
# Run 0068 | Score: -715330.8 | Exploration Rate: 0.665
# Run 0069 | Score: -729020.4 | Exploration Rate: 0.661
# Run 0070 | Score: -745801.8 | Exploration Rate: 0.657
# Run 0071 | Score: -526699.8 | Exploration Rate: 0.654
# Run 0072 | Score: -537173.4 | Exploration Rate: 0.650
# Run 0073 | Score: -524112.6 | Exploration Rate: 0.646
# Run 0074 | Score: -620447.4 | Exploration Rate: 0.642
# Run 0075 | Score: -546587.4 | Exploration Rate: 0.638
# Run 0076 | Score: -525923.4 | Exploration Rate: 0.634
# Run 0077 | Score: -538570.8 | Exploration Rate: 0.630
# Run 0078 | Score: -664842.0 | Exploration Rate: 0.627
# Run 0079 | Score: -507141.0 | Exploration Rate: 0.623
# Run 0080 | Score: -567965.4 | Exploration Rate: 0.619
# Run 0081 | Score: -570175.2 | Exploration Rate: 0.616
# Run 0082 | Score: -483682.8 | Exploration Rate: 0.612
# Run 0083 | Score: -692527.8 | Exploration Rate: 0.608
# Run 0084 | Score: -460731.0 | Exploration Rate: 0.605
# Run 0085 | Score: -451932.0 | Exploration Rate: 0.601
# Run 0086 | Score: -507089.4 | Exploration Rate: 0.597
# Run 0087 | Score: -680893.2 | Exploration Rate: 0.594
# Run 0088 | Score: -431646.0 | Exploration Rate: 0.590
# Run 0089 | Score: -436389.6 | Exploration Rate: 0.587
# Run 0090 | Score: -526884.0 | Exploration Rate: 0.583
# Run 0091 | Score: -497856.6 | Exploration Rate: 0.580
# Run 0092 | Score: -430930.8 | Exploration Rate: 0.576
# Run 0093 | Score: -472005.0 | Exploration Rate: 0.573
# Run 0094 | Score: -485473.8 | Exploration Rate: 0.569
# Run 0095 | Score: -447826.8 | Exploration Rate: 0.566
# Run 0096 | Score: -415617.0 | Exploration Rate: 0.563
# Run 0097 | Score: -857639.4 | Exploration Rate: 0.559
# Run 0098 | Score: -515423.4 | Exploration Rate: 0.556
# Run 0099 | Score: -523918.8 | Exploration Rate: 0.553
# Run 0100 | Score: -470285.4 | Exploration Rate: 0.549
# Run 0101 | Score: -565905.6 | Exploration Rate: 0.546
# Run 0102 | Score: -472297.2 | Exploration Rate: 0.543
# Run 0103 | Score: -515781.0 | Exploration Rate: 0.539
# Run 0104 | Score: -426767.4 | Exploration Rate: 0.536
# Run 0105 | Score: -413180.4 | Exploration Rate: 0.533
# Run 0106 | Score: -431080.2 | Exploration Rate: 0.530
# Run 0107 | Score: -471595.8 | Exploration Rate: 0.527
# Run 0108 | Score: -437965.2 | Exploration Rate: 0.524
# Run 0109 | Score: -431928.6 | Exploration Rate: 0.520
# Run 0110 | Score: -398163.6 | Exploration Rate: 0.517
# Run 0111 | Score: -491399.4 | Exploration Rate: 0.514
# Run 0112 | Score: -390290.4 | Exploration Rate: 0.511
# Run 0113 | Score: -447540.6 | Exploration Rate: 0.508
# Run 0114 | Score: -385778.4 | Exploration Rate: 0.505
# Run 0115 | Score: -394256.4 | Exploration Rate: 0.502
# Run 0116 | Score: -398080.8 | Exploration Rate: 0.499
# Run 0117 | Score: -426801.0 | Exploration Rate: 0.496
# Run 0118 | Score: -396952.8 | Exploration Rate: 0.493
# Run 0119 | Score: -416036.4 | Exploration Rate: 0.490
# Run 0120 | Score: -397611.0 | Exploration Rate: 0.487
# Run 0121 | Score: -380970.0 | Exploration Rate: 0.484
# Run 0122 | Score: -384902.4 | Exploration Rate: 0.481
# Run 0123 | Score: -612714.6 | Exploration Rate: 0.479
# Run 0124 | Score: -379103.4 | Exploration Rate: 0.476
# Run 0125 | Score: -368578.2 | Exploration Rate: 0.473
# Run 0126 | Score: -388209.6 | Exploration Rate: 0.470
# Run 0127 | Score: -366137.4 | Exploration Rate: 0.467
# Run 0128 | Score: -427852.8 | Exploration Rate: 0.464
# Run 0129 | Score: -365643.0 | Exploration Rate: 0.462
# Run 0130 | Score: -391944.0 | Exploration Rate: 0.459
# Run 0131 | Score: -392870.4 | Exploration Rate: 0.456
# Run 0132 | Score: -376193.4 | Exploration Rate: 0.453
# Run 0133 | Score: -390222.0 | Exploration Rate: 0.451
# Run 0134 | Score: -347555.4 | Exploration Rate: 0.448
# Run 0135 | Score: -367579.8 | Exploration Rate: 0.445
# Run 0136 | Score: -356293.2 | Exploration Rate: 0.443
# Run 0137 | Score: -343953.6 | Exploration Rate: 0.440
# Run 0138 | Score: -414988.8 | Exploration Rate: 0.437
# Run 0139 | Score: -383950.2 | Exploration Rate: 0.435
# Run 0140 | Score: -368078.4 | Exploration Rate: 0.432
# Run 0141 | Score: -420967.8 | Exploration Rate: 0.430
# Run 0142 | Score: -359035.2 | Exploration Rate: 0.427
# Run 0143 | Score: -388436.4 | Exploration Rate: 0.425
# Run 0144 | Score: -463978.2 | Exploration Rate: 0.422
# Run 0145 | Score: -355948.2 | Exploration Rate: 0.419
# Run 0146 | Score: -359500.8 | Exploration Rate: 0.417
# Run 0147 | Score: -358140.0 | Exploration Rate: 0.414
# Run 0148 | Score: -387417.6 | Exploration Rate: 0.412
# Run 0149 | Score: -380680.2 | Exploration Rate: 0.410
# Run 0150 | Score: -329365.2 | Exploration Rate: 0.407
# Run 0151 | Score: -350667.6 | Exploration Rate: 0.405
# Run 0152 | Score: -340508.4 | Exploration Rate: 0.402
# Run 0153 | Score: -376831.8 | Exploration Rate: 0.400
# Run 0154 | Score: -348739.2 | Exploration Rate: 0.397
# Run 0155 | Score: -345556.8 | Exploration Rate: 0.395
# Run 0156 | Score: -303888.0 | Exploration Rate: 0.393
# Run 0157 | Score: -385769.4 | Exploration Rate: 0.390
# Run 0158 | Score: -330961.2 | Exploration Rate: 0.388
# Run 0159 | Score: -320179.2 | Exploration Rate: 0.386
# Run 0160 | Score: -382959.0 | Exploration Rate: 0.383
# Run 0161 | Score: -355591.8 | Exploration Rate: 0.381
# Run 0162 | Score: -319308.6 | Exploration Rate: 0.379
# Run 0163 | Score: -367448.4 | Exploration Rate: 0.377
# Run 0164 | Score: -338440.2 | Exploration Rate: 0.374
# Run 0165 | Score: -378042.0 | Exploration Rate: 0.372
# Run 0166 | Score: -389782.8 | Exploration Rate: 0.370
# Run 0167 | Score: -347137.2 | Exploration Rate: 0.368
# Run 0168 | Score: -339263.4 | Exploration Rate: 0.365
# Run 0169 | Score: -476389.2 | Exploration Rate: 0.363
# Run 0170 | Score: -360528.6 | Exploration Rate: 0.361
# Run 0171 | Score: -404603.4 | Exploration Rate: 0.359
# Run 0172 | Score: -350345.4 | Exploration Rate: 0.357
# Run 0173 | Score: -394715.4 | Exploration Rate: 0.355
# Run 0174 | Score: -340434.0 | Exploration Rate: 0.353
# Run 0175 | Score: -391514.4 | Exploration Rate: 0.350
# Run 0176 | Score: -358432.2 | Exploration Rate: 0.348
# Run 0177 | Score: -439163.4 | Exploration Rate: 0.346
# Run 0178 | Score: -365558.4 | Exploration Rate: 0.344
# Run 0179 | Score: -448038.6 | Exploration Rate: 0.342
# Run 0180 | Score: -393716.4 | Exploration Rate: 0.340
# Run 0181 | Score: -410670.6 | Exploration Rate: 0.338
# Run 0182 | Score: -365338.2 | Exploration Rate: 0.336
# Run 0183 | Score: -345936.6 | Exploration Rate: 0.334
# Run 0184 | Score: -370281.0 | Exploration Rate: 0.332
# Run 0185 | Score: -342380.4 | Exploration Rate: 0.330
# Run 0186 | Score: -368145.0 | Exploration Rate: 0.328
# Run 0187 | Score: -354935.4 | Exploration Rate: 0.326
# Run 0188 | Score: -311929.8 | Exploration Rate: 0.324
# Run 0189 | Score: -339408.0 | Exploration Rate: 0.322
# Run 0190 | Score: -366086.4 | Exploration Rate: 0.320
# Run 0191 | Score: -399055.8 | Exploration Rate: 0.318
# Run 0192 | Score: -363678.0 | Exploration Rate: 0.317
# Run 0193 | Score: -354867.6 | Exploration Rate: 0.315
# Run 0194 | Score: -388463.4 | Exploration Rate: 0.313
# Run 0195 | Score: -411717.0 | Exploration Rate: 0.311
# Run 0196 | Score: -354508.2 | Exploration Rate: 0.309
# Run 0197 | Score: -322164.6 | Exploration Rate: 0.307
# Run 0198 | Score: -316087.2 | Exploration Rate: 0.305
# Run 0199 | Score: -354910.2 | Exploration Rate: 0.304
# Run 0200 | Score: -356946.6 | Exploration Rate: 0.302
# Run 0201 | Score: -358023.0 | Exploration Rate: 0.300
# Run 0202 | Score: -328674.0 | Exploration Rate: 0.298
# Run 0203 | Score: -300335.4 | Exploration Rate: 0.296
# Run 0204 | Score: -348499.8 | Exploration Rate: 0.295
# Run 0205 | Score: -330100.2 | Exploration Rate: 0.293
# Run 0206 | Score: -309703.2 | Exploration Rate: 0.291
# Run 0207 | Score: -328082.4 | Exploration Rate: 0.289
# Run 0208 | Score: -346433.4 | Exploration Rate: 0.288
# Run 0209 | Score: -355654.2 | Exploration Rate: 0.286
# Run 0210 | Score: -364558.8 | Exploration Rate: 0.284
# Run 0211 | Score: -310174.8 | Exploration Rate: 0.282
# Run 0212 | Score: -590292.6 | Exploration Rate: 0.281
# Run 0213 | Score: -377229.6 | Exploration Rate: 0.279
# Run 0214 | Score: -350212.8 | Exploration Rate: 0.277
# Run 0215 | Score: -316928.4 | Exploration Rate: 0.276
# Run 0216 | Score: -384670.2 | Exploration Rate: 0.274
# Run 0217 | Score: -377409.0 | Exploration Rate: 0.272
# Run 0218 | Score: -359305.8 | Exploration Rate: 0.271
# Run 0219 | Score: -363351.0 | Exploration Rate: 0.269
# Run 0220 | Score: -367051.2 | Exploration Rate: 0.268
# Run 0221 | Score: -293365.8 | Exploration Rate: 0.266
# Run 0222 | Score: -324565.8 | Exploration Rate: 0.264
# Run 0223 | Score: -338501.4 | Exploration Rate: 0.263
# Run 0224 | Score: -350142.6 | Exploration Rate: 0.261
# Run 0225 | Score: -344689.8 | Exploration Rate: 0.260
# Run 0226 | Score: -329675.4 | Exploration Rate: 0.258
# Run 0227 | Score: -350965.8 | Exploration Rate: 0.257
# Run 0228 | Score: -308980.2 | Exploration Rate: 0.255
# Run 0229 | Score: -331154.4 | Exploration Rate: 0.254
# Run 0230 | Score: -376516.2 | Exploration Rate: 0.252
# Run 0231 | Score: -330190.2 | Exploration Rate: 0.251
# Run 0232 | Score: -340753.2 | Exploration Rate: 0.249
# Run 0233 | Score: -333078.0 | Exploration Rate: 0.248
# Run 0234 | Score: -323969.4 | Exploration Rate: 0.246
# Run 0235 | Score: -287702.4 | Exploration Rate: 0.245
# Run 0236 | Score: -268478.4 | Exploration Rate: 0.243
# Run 0237 | Score: -306297.6 | Exploration Rate: 0.242
# Run 0238 | Score: -324927.0 | Exploration Rate: 0.240
# Run 0239 | Score: -310221.0 | Exploration Rate: 0.239
# Run 0240 | Score: -345016.8 | Exploration Rate: 0.237
# Run 0241 | Score: -315242.4 | Exploration Rate: 0.236
# Run 0242 | Score: -309530.4 | Exploration Rate: 0.235
# Run 0243 | Score: -304338.6 | Exploration Rate: 0.233
# Run 0244 | Score: -285355.8 | Exploration Rate: 0.232
# Run 0245 | Score: -295904.4 | Exploration Rate: 0.230
# Run 0246 | Score: -315468.0 | Exploration Rate: 0.229
# Run 0247 | Score: -396395.4 | Exploration Rate: 0.228
# Run 0248 | Score: -310768.8 | Exploration Rate: 0.226
# Run 0249 | Score: -302448.6 | Exploration Rate: 0.225
# Run 0250 | Score: -291811.2 | Exploration Rate: 0.224
# --> Checkpoint secured: d3qn_gat_250.pth
# Run 0251 | Score: -301944.0 | Exploration Rate: 0.222
# Run 0252 | Score: -323076.6 | Exploration Rate: 0.221
# Run 0253 | Score: -303635.4 | Exploration Rate: 0.220
# Run 0254 | Score: -301180.2 | Exploration Rate: 0.218
# Run 0255 | Score: -332580.6 | Exploration Rate: 0.217
# Run 0256 | Score: -351334.8 | Exploration Rate: 0.216
# Run 0257 | Score: -334392.6 | Exploration Rate: 0.214
# Run 0258 | Score: -346974.0 | Exploration Rate: 0.213
# Run 0259 | Score: -382939.2 | Exploration Rate: 0.212
# Run 0260 | Score: -378796.2 | Exploration Rate: 0.211
# Run 0261 | Score: -282175.2 | Exploration Rate: 0.209
# Run 0262 | Score: -322811.4 | Exploration Rate: 0.208
# Run 0263 | Score: -330880.2 | Exploration Rate: 0.207
# Run 0264 | Score: -322177.8 | Exploration Rate: 0.206
# Run 0265 | Score: -333976.8 | Exploration Rate: 0.204
# Run 0266 | Score: -355711.2 | Exploration Rate: 0.203
# Run 0267 | Score: -364789.2 | Exploration Rate: 0.202
# Run 0268 | Score: -330268.2 | Exploration Rate: 0.201
# Run 0269 | Score: -309340.2 | Exploration Rate: 0.200
# Run 0270 | Score: -320076.6 | Exploration Rate: 0.198
# Run 0271 | Score: -296785.2 | Exploration Rate: 0.197
# Run 0272 | Score: -328965.6 | Exploration Rate: 0.196
# Run 0273 | Score: -337867.2 | Exploration Rate: 0.195
# Run 0274 | Score: -302571.0 | Exploration Rate: 0.194
# Run 0275 | Score: -356638.8 | Exploration Rate: 0.193
# Run 0276 | Score: -337330.8 | Exploration Rate: 0.191
# Run 0277 | Score: -312742.2 | Exploration Rate: 0.190
# Run 0278 | Score: -406413.6 | Exploration Rate: 0.189
# Run 0279 | Score: -407849.4 | Exploration Rate: 0.188
# Run 0280 | Score: -345457.2 | Exploration Rate: 0.187
# Run 0281 | Score: -288738.0 | Exploration Rate: 0.186
# Run 0282 | Score: -320043.6 | Exploration Rate: 0.185
# Run 0283 | Score: -300984.6 | Exploration Rate: 0.183
# Run 0284 | Score: -315152.4 | Exploration Rate: 0.182
# Run 0285 | Score: -492656.4 | Exploration Rate: 0.181
# Run 0286 | Score: -337754.4 | Exploration Rate: 0.180
# Run 0287 | Score: -325003.2 | Exploration Rate: 0.179
# Run 0288 | Score: -332055.0 | Exploration Rate: 0.178
# Run 0289 | Score: -330048.6 | Exploration Rate: 0.177
# Run 0290 | Score: -429790.8 | Exploration Rate: 0.176
# Run 0291 | Score: -389458.8 | Exploration Rate: 0.175
# Run 0292 | Score: -347383.8 | Exploration Rate: 0.174
# Run 0293 | Score: -371581.2 | Exploration Rate: 0.173
# Run 0294 | Score: -373341.6 | Exploration Rate: 0.172
# Run 0295 | Score: -322505.4 | Exploration Rate: 0.171
# Run 0296 | Score: -283883.4 | Exploration Rate: 0.170
# Run 0297 | Score: -313371.6 | Exploration Rate: 0.169
# Run 0298 | Score: -289203.6 | Exploration Rate: 0.168
# Run 0299 | Score: -304789.2 | Exploration Rate: 0.167
# Run 0300 | Score: -306648.6 | Exploration Rate: 0.166
# Run 0301 | Score: -287895.0 | Exploration Rate: 0.165
# Run 0302 | Score: -357676.8 | Exploration Rate: 0.164
# Run 0303 | Score: -321553.2 | Exploration Rate: 0.163
# Run 0304 | Score: -324685.8 | Exploration Rate: 0.162
# Run 0305 | Score: -297988.2 | Exploration Rate: 0.161
# Run 0306 | Score: -266293.2 | Exploration Rate: 0.160
# Run 0307 | Score: -305012.4 | Exploration Rate: 0.159
# Run 0308 | Score: -272663.4 | Exploration Rate: 0.158
# Run 0309 | Score: -264658.8 | Exploration Rate: 0.157
# Run 0310 | Score: -287637.0 | Exploration Rate: 0.156
# Run 0311 | Score: -294340.8 | Exploration Rate: 0.155
# Run 0312 | Score: -301425.0 | Exploration Rate: 0.154
# Run 0313 | Score: -289978.2 | Exploration Rate: 0.153
# Run 0314 | Score: -318112.8 | Exploration Rate: 0.152
# Run 0315 | Score: -272127.6 | Exploration Rate: 0.151
# Run 0316 | Score: -262549.8 | Exploration Rate: 0.151
# Run 0317 | Score: -289244.4 | Exploration Rate: 0.150
# Run 0318 | Score: -324006.0 | Exploration Rate: 0.149
# Run 0319 | Score: -293207.4 | Exploration Rate: 0.148
# Run 0320 | Score: -310245.6 | Exploration Rate: 0.147
# Run 0321 | Score: -297054.6 | Exploration Rate: 0.146
# Run 0322 | Score: -294913.2 | Exploration Rate: 0.145
# Run 0323 | Score: -296019.6 | Exploration Rate: 0.144
# Run 0324 | Score: -283330.8 | Exploration Rate: 0.144
# Run 0325 | Score: -297970.8 | Exploration Rate: 0.143
# Run 0326 | Score: -332754.0 | Exploration Rate: 0.142
# Run 0327 | Score: -295696.8 | Exploration Rate: 0.141
# Run 0328 | Score: -335776.8 | Exploration Rate: 0.140
# Run 0329 | Score: -297022.8 | Exploration Rate: 0.139
# Run 0330 | Score: -339774.6 | Exploration Rate: 0.138
# Run 0331 | Score: -338280.0 | Exploration Rate: 0.138
# Run 0332 | Score: -313773.6 | Exploration Rate: 0.137
# Run 0333 | Score: -348342.0 | Exploration Rate: 0.136
# Run 0334 | Score: -376960.2 | Exploration Rate: 0.135
# Run 0335 | Score: -313478.4 | Exploration Rate: 0.134
# Run 0336 | Score: -307962.6 | Exploration Rate: 0.134
# Run 0337 | Score: -287920.2 | Exploration Rate: 0.133
# Run 0338 | Score: -315985.2 | Exploration Rate: 0.132
# Run 0339 | Score: -288939.6 | Exploration Rate: 0.131
# Run 0340 | Score: -313764.6 | Exploration Rate: 0.130
# Run 0341 | Score: -332024.4 | Exploration Rate: 0.130
# Run 0342 | Score: -301003.2 | Exploration Rate: 0.129
# Run 0343 | Score: -298269.0 | Exploration Rate: 0.128
# Run 0344 | Score: -360698.4 | Exploration Rate: 0.127
# Run 0345 | Score: -288080.4 | Exploration Rate: 0.127
# Run 0346 | Score: -271279.2 | Exploration Rate: 0.126
# Run 0347 | Score: -359187.0 | Exploration Rate: 0.125
# Run 0348 | Score: -271193.4 | Exploration Rate: 0.124
# Run 0349 | Score: -328343.4 | Exploration Rate: 0.124
# Run 0350 | Score: -309949.2 | Exploration Rate: 0.123
# Run 0351 | Score: -285185.4 | Exploration Rate: 0.122
# Run 0352 | Score: -273531.6 | Exploration Rate: 0.121
# Run 0353 | Score: -290586.0 | Exploration Rate: 0.121
# Run 0354 | Score: -321384.0 | Exploration Rate: 0.120
# Run 0355 | Score: -266952.6 | Exploration Rate: 0.119
# Run 0356 | Score: -252044.4 | Exploration Rate: 0.118
# Run 0357 | Score: -254631.6 | Exploration Rate: 0.118
# Run 0358 | Score: -287903.4 | Exploration Rate: 0.117
# Run 0359 | Score: -297793.8 | Exploration Rate: 0.116
# Run 0360 | Score: -312702.0 | Exploration Rate: 0.116
# Run 0361 | Score: -265570.8 | Exploration Rate: 0.115
# Run 0362 | Score: -313959.6 | Exploration Rate: 0.114
# Run 0363 | Score: -279988.8 | Exploration Rate: 0.114
# Run 0364 | Score: -316707.6 | Exploration Rate: 0.113
# Run 0365 | Score: -237834.6 | Exploration Rate: 0.112
# Run 0366 | Score: -319019.4 | Exploration Rate: 0.112
# Run 0367 | Score: -288251.4 | Exploration Rate: 0.111
# Run 0368 | Score: -255556.2 | Exploration Rate: 0.110
# Run 0369 | Score: -274871.4 | Exploration Rate: 0.110
# Run 0370 | Score: -290763.6 | Exploration Rate: 0.109
# Run 0371 | Score: -268681.2 | Exploration Rate: 0.108
# Run 0372 | Score: -279293.4 | Exploration Rate: 0.108
# Run 0373 | Score: -274894.2 | Exploration Rate: 0.107
# Run 0374 | Score: -271681.2 | Exploration Rate: 0.106
# Run 0375 | Score: -335717.4 | Exploration Rate: 0.106
# Run 0376 | Score: -300625.8 | Exploration Rate: 0.105
# Run 0377 | Score: -278602.2 | Exploration Rate: 0.104
# Run 0378 | Score: -320662.8 | Exploration Rate: 0.104
# Run 0379 | Score: -298561.2 | Exploration Rate: 0.103
# Run 0380 | Score: -299851.2 | Exploration Rate: 0.103
# Run 0381 | Score: -258899.4 | Exploration Rate: 0.102
# Run 0382 | Score: -269800.2 | Exploration Rate: 0.101
# Run 0383 | Score: -297715.2 | Exploration Rate: 0.101
# Run 0384 | Score: -352480.8 | Exploration Rate: 0.100
# Run 0385 | Score: -323104.8 | Exploration Rate: 0.100
# Run 0386 | Score: -273745.2 | Exploration Rate: 0.099
# Run 0387 | Score: -319851.0 | Exploration Rate: 0.098
# Run 0388 | Score: -316404.6 | Exploration Rate: 0.098
# Run 0389 | Score: -306174.6 | Exploration Rate: 0.097
# Run 0390 | Score: -320900.4 | Exploration Rate: 0.097
# Run 0391 | Score: -326101.8 | Exploration Rate: 0.096
# Run 0392 | Score: -342358.8 | Exploration Rate: 0.095
# Run 0393 | Score: -299680.8 | Exploration Rate: 0.095
# Run 0394 | Score: -363537.0 | Exploration Rate: 0.094
# Run 0395 | Score: -320208.6 | Exploration Rate: 0.094
# Run 0396 | Score: -304640.4 | Exploration Rate: 0.093
# Run 0397 | Score: -292629.0 | Exploration Rate: 0.093
# Run 0398 | Score: -289297.2 | Exploration Rate: 0.092
# Run 0399 | Score: -312890.4 | Exploration Rate: 0.092
# Run 0400 | Score: -316359.0 | Exploration Rate: 0.091
# Run 0401 | Score: -314920.2 | Exploration Rate: 0.090
# Run 0402 | Score: -291906.0 | Exploration Rate: 0.090
# Run 0403 | Score: -343297.8 | Exploration Rate: 0.089
# Run 0404 | Score: -305020.2 | Exploration Rate: 0.089
# Run 0405 | Score: -340045.8 | Exploration Rate: 0.088
# Run 0406 | Score: -281216.4 | Exploration Rate: 0.088
# Run 0407 | Score: -312619.2 | Exploration Rate: 0.087
# Run 0408 | Score: -314498.4 | Exploration Rate: 0.087
# Run 0409 | Score: -245314.2 | Exploration Rate: 0.086
# Run 0410 | Score: -283558.2 | Exploration Rate: 0.086
# Run 0411 | Score: -289157.4 | Exploration Rate: 0.085
# Run 0412 | Score: -282653.4 | Exploration Rate: 0.085
# Run 0413 | Score: -285888.0 | Exploration Rate: 0.084
# Run 0414 | Score: -271759.2 | Exploration Rate: 0.084
# Run 0415 | Score: -326430.0 | Exploration Rate: 0.083
# Run 0416 | Score: -256545.0 | Exploration Rate: 0.083
# Run 0417 | Score: -272834.4 | Exploration Rate: 0.082
# Run 0418 | Score: -267557.4 | Exploration Rate: 0.082
# Run 0419 | Score: -318192.6 | Exploration Rate: 0.081
# Run 0420 | Score: -290505.0 | Exploration Rate: 0.081
# Run 0421 | Score: -298124.4 | Exploration Rate: 0.080
# Run 0422 | Score: -261345.0 | Exploration Rate: 0.080
# Run 0423 | Score: -281048.4 | Exploration Rate: 0.079
# Run 0424 | Score: -261910.2 | Exploration Rate: 0.079
# Run 0425 | Score: -315164.4 | Exploration Rate: 0.078
# Run 0426 | Score: -252677.4 | Exploration Rate: 0.078
# Run 0427 | Score: -271052.4 | Exploration Rate: 0.077
# Run 0428 | Score: -291232.2 | Exploration Rate: 0.077
# Run 0429 | Score: -283451.4 | Exploration Rate: 0.077
# Run 0430 | Score: -275108.4 | Exploration Rate: 0.076
# Run 0431 | Score: -245299.2 | Exploration Rate: 0.076
# Run 0432 | Score: -273243.6 | Exploration Rate: 0.075
# Run 0433 | Score: -269778.0 | Exploration Rate: 0.075
# Run 0434 | Score: -313627.2 | Exploration Rate: 0.074
# Run 0435 | Score: -268988.4 | Exploration Rate: 0.074
# Run 0436 | Score: -260555.4 | Exploration Rate: 0.073
# Run 0437 | Score: -250777.2 | Exploration Rate: 0.073
# Run 0438 | Score: -344590.2 | Exploration Rate: 0.072
# Run 0439 | Score: -292453.2 | Exploration Rate: 0.072
# Run 0440 | Score: -286520.4 | Exploration Rate: 0.072
# Run 0441 | Score: -262965.6 | Exploration Rate: 0.071
# Run 0442 | Score: -288759.0 | Exploration Rate: 0.071
# Run 0443 | Score: -284284.8 | Exploration Rate: 0.070
# Run 0444 | Score: -278789.4 | Exploration Rate: 0.070
# Run 0445 | Score: -270201.0 | Exploration Rate: 0.070
# Run 0446 | Score: -291064.2 | Exploration Rate: 0.069
# Run 0447 | Score: -293241.0 | Exploration Rate: 0.069
# Run 0448 | Score: -260992.2 | Exploration Rate: 0.068
# Run 0449 | Score: -237790.8 | Exploration Rate: 0.068
# Run 0450 | Score: -296788.2 | Exploration Rate: 0.067
# Run 0451 | Score: -297369.6 | Exploration Rate: 0.067
# Run 0452 | Score: -310617.0 | Exploration Rate: 0.067
# Run 0453 | Score: -283026.0 | Exploration Rate: 0.066
# Run 0454 | Score: -249994.8 | Exploration Rate: 0.066
# Run 0455 | Score: -308799.0 | Exploration Rate: 0.065
# Run 0456 | Score: -267282.0 | Exploration Rate: 0.065
# Run 0457 | Score: -266893.2 | Exploration Rate: 0.065
# Run 0458 | Score: -249557.4 | Exploration Rate: 0.064
# Run 0459 | Score: -281698.8 | Exploration Rate: 0.064
# Run 0460 | Score: -273619.8 | Exploration Rate: 0.064
# Run 0461 | Score: -283369.2 | Exploration Rate: 0.063
# Run 0462 | Score: -289560.0 | Exploration Rate: 0.063
# Run 0463 | Score: -234412.8 | Exploration Rate: 0.062
# Run 0464 | Score: -242698.2 | Exploration Rate: 0.062
# Run 0465 | Score: -307317.0 | Exploration Rate: 0.062
# Run 0466 | Score: -276508.2 | Exploration Rate: 0.061
# Run 0467 | Score: -268368.6 | Exploration Rate: 0.061
# Run 0468 | Score: -262288.8 | Exploration Rate: 0.061
# Run 0469 | Score: -269990.4 | Exploration Rate: 0.060
# Run 0470 | Score: -244211.4 | Exploration Rate: 0.060
# Run 0471 | Score: -245870.4 | Exploration Rate: 0.059
# Run 0472 | Score: -231097.8 | Exploration Rate: 0.059
# Run 0473 | Score: -277854.6 | Exploration Rate: 0.059
# Run 0474 | Score: -287431.8 | Exploration Rate: 0.058
# Run 0475 | Score: -265530.6 | Exploration Rate: 0.058
# Run 0476 | Score: -272288.4 | Exploration Rate: 0.058
# Run 0477 | Score: -297496.8 | Exploration Rate: 0.057
# Run 0478 | Score: -320988.6 | Exploration Rate: 0.057
# Run 0479 | Score: -294911.4 | Exploration Rate: 0.057
# Run 0480 | Score: -284145.6 | Exploration Rate: 0.056
# Run 0481 | Score: -373702.8 | Exploration Rate: 0.056
# Run 0482 | Score: -289278.6 | Exploration Rate: 0.056
# Run 0483 | Score: -312942.6 | Exploration Rate: 0.055
# Run 0484 | Score: -231902.4 | Exploration Rate: 0.055
# Run 0485 | Score: -270757.8 | Exploration Rate: 0.055
# Run 0486 | Score: -303904.2 | Exploration Rate: 0.054
# Run 0487 | Score: -254422.2 | Exploration Rate: 0.054
# Run 0488 | Score: -309470.4 | Exploration Rate: 0.054
# Run 0489 | Score: -268684.8 | Exploration Rate: 0.053
# Run 0490 | Score: -306975.6 | Exploration Rate: 0.053
# Run 0491 | Score: -286936.8 | Exploration Rate: 0.053
# Run 0492 | Score: -259622.4 | Exploration Rate: 0.052
# Run 0493 | Score: -260955.0 | Exploration Rate: 0.052
# Run 0494 | Score: -287103.0 | Exploration Rate: 0.052
# Run 0495 | Score: -292125.6 | Exploration Rate: 0.052
# Run 0496 | Score: -261609.6 | Exploration Rate: 0.051
# Run 0497 | Score: -294663.0 | Exploration Rate: 0.051
# Run 0498 | Score: -309836.4 | Exploration Rate: 0.051
# Run 0499 | Score: -277806.0 | Exploration Rate: 0.050
# Run 0500 | Score: -315963.6 | Exploration Rate: 0.050
# --> Checkpoint secured: d3qn_gat_500.pth
#
# Training Complete. Final model stored at project_weights/gat_d3qn_run/loop_d3qn_gat.pth
