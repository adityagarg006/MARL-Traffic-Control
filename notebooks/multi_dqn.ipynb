# %%
import os
import random
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import gym
import cityflow
import gym_cityflow

# Configure hardware acceleration
hardware_device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Active Compute Device: {hardware_device}")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Active Compute Device: cuda

# %%
# CELL 2: Neural Network and Reward Scaler
class TrafficIntersectionBrain(nn.Module):
    """A high-capacity Multi-Layer Perceptron using Sequential blocks."""
    def __init__(self, features_in, num_actions, layer_widths=[128, 256, 128]):
        super(TrafficIntersectionBrain, self).__init__()
        
        self.network = nn.Sequential(
            nn.Linear(features_in, layer_widths[0]),
            nn.LayerNorm(layer_widths[0]),
            nn.ReLU(),
            
            nn.Linear(layer_widths[0], layer_widths[1]),
            nn.LayerNorm(layer_widths[1]),
            nn.ReLU(),
            
            nn.Linear(layer_widths[1], layer_widths[2]),
            nn.LayerNorm(layer_widths[2]),
            nn.ReLU(),
            
            nn.Linear(layer_widths[2], num_actions)
        )

    def forward(self, x):
        return self.network(x)


class RunningRewardScaler:
    """Standalone class to track running variance and normalize rewards."""
    def __init__(self, decay_rate=0.001, epsilon=1e-8):
        self.running_mean = 0.0
        self.running_variance = 1.0
        self.decay_rate = decay_rate
        self.epsilon = epsilon

    def scale(self, reward_array):
        # Calculate stats for the current batch
        current_mean = np.mean(reward_array)
        current_var = np.var(reward_array)
        
        # Update running metrics
        self.running_mean += self.decay_rate * (current_mean - self.running_mean)
        self.running_variance += self.decay_rate * (current_var - self.running_variance)
        
        # Apply normalization
        scaled_rewards = (reward_array - self.running_mean) / (np.sqrt(self.running_variance) + self.epsilon)
        return scaled_rewards

# %%
# CELL 3: Experience Replay (Flattened Architecture)
class SharedExperienceMemory:
    """Stores individual agent transitions linearly to prevent multi-dim reshaping during training."""
    def __init__(self, max_capacity, feature_dim):
        self.capacity = max_capacity
        self.ptr = 0
        self.current_count = 0
        
        self.s_mem = np.zeros((max_capacity, feature_dim), dtype=np.float32)
        self.s_next_mem = np.zeros((max_capacity, feature_dim), dtype=np.float32)
        self.a_mem = np.zeros(max_capacity, dtype=np.int64)
        self.r_mem = np.zeros(max_capacity, dtype=np.float32)
        self.done_mem = np.zeros(max_capacity, dtype=np.float32)

    def add_transitions(self, state_list, action_list, next_state_list, reward_list, done_flag):
        # Ingest a list of experiences simultaneously
        num_inserts = len(state_list)
        for i in range(num_inserts):
            self.s_mem[self.ptr] = state_list[i]
            self.a_mem[self.ptr] = action_list[i]
            self.s_next_mem[self.ptr] = next_state_list[i]
            self.r_mem[self.ptr] = reward_list[i]
            self.done_mem[self.ptr] = float(done_flag)
            
            self.ptr = (self.ptr + 1) % self.capacity
            self.current_count = min(self.current_count + 1, self.capacity)

    def draw_batch(self, sample_size):
        indices = np.random.randint(0, self.current_count, size=sample_size)
        return (
            self.s_mem[indices],
            self.a_mem[indices],
            self.r_mem[indices],
            self.s_next_mem[indices],
            self.done_mem[indices]
        )

    def __len__(self):
        return self.current_count

# %%
# CELL 4: Central Multi-Agent Controller
class GlobalTrafficCoordinator:
    def __init__(self, state_size, action_size, total_agents, config):
        self.action_size = action_size
        self.cfg = config
        
        # Exploration parameters
        self.explore_rate = config['initial_eps']
        self.explore_floor = config['min_eps']
        self.explore_decay = config['decay_eps']
        
        # Sub-modules
        self.reward_processor = RunningRewardScaler()
        # Flatten the buffer size to account for all agents
        total_buffer_capacity = config['buffer_limit'] * total_agents
        self.memory = SharedExperienceMemory(total_buffer_capacity, state_size)
        
        # Networks
        self.policy_net = TrafficIntersectionBrain(state_size, action_size).to(hardware_device)
        self.stable_net = TrafficIntersectionBrain(state_size, action_size).to(hardware_device)
        self.stable_net.load_state_dict(self.policy_net.state_dict())
        self.stable_net.eval()
        
        self.opt = optim.Adam(self.policy_net.parameters(), lr=config['learning_rate'])
        self.interaction_steps = 0

    def pick_actions(self, observations):
        chosen_actions = []
        for obs in observations:
            if random.random() < self.explore_rate:
                chosen_actions.append(random.randrange(self.action_size))
            else:
                with torch.no_grad():
                    state_t = torch.tensor(obs, dtype=torch.float32, device=hardware_device).unsqueeze(0)
                    predictions = self.policy_net(state_t)
                    chosen_actions.append(predictions.argmax().item())
        return chosen_actions

    def record_and_train(self, s, a, s_next, r, is_done):
        # 1. Scale rewards
        r_array = np.array(r, dtype=np.float32)
        scaled_r = self.reward_processor.scale(r_array)
        
        # 2. Store flattened transitions
        self.memory.add_transitions(s, a, s_next, scaled_r, is_done)
        
        # 3. Optimize
        self.interaction_steps += 1
        if len(self.memory) >= self.cfg['batch_sz'] and self.interaction_steps % self.cfg['update_freq'] == 0:
            self._optimize_weights()
            
        # 4. Sync Target Network
        if self.interaction_steps % self.cfg['sync_freq'] == 0:
            self.stable_net.load_state_dict(self.policy_net.state_dict())

    def decay_exploration(self):
        self.explore_rate = max(self.explore_floor, self.explore_rate * self.explore_decay)

    def _optimize_weights(self):
        s_b, a_b, r_b, s_next_b, done_b = self.memory.draw_batch(self.cfg['batch_sz'])
        
        states = torch.FloatTensor(s_b).to(hardware_device)
        actions = torch.LongTensor(a_b).unsqueeze(1).to(hardware_device)
        rewards = torch.FloatTensor(r_b).unsqueeze(1).to(hardware_device)
        next_states = torch.FloatTensor(s_next_b).to(hardware_device)
        dones = torch.FloatTensor(done_b).unsqueeze(1).to(hardware_device)

        # Current Q
        current_q = self.policy_net(states).gather(1, actions)
        
        # Standard DQN Target Calculation
        with torch.no_grad():
            # The stable_net (target network) simply finds its own maximum value
            future_q = self.stable_net(next_states).max(dim=1, keepdim=True)[0]
            target_q = rewards + self.cfg['gamma'] * future_q * (1 - dones)

        # Huber Loss
        loss = F.smooth_l1_loss(current_q, target_q)
        
        self.opt.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), self.cfg['grad_clip'])
        self.opt.step()

# %%
# CELL 5: Training Execution Logic
def execute_simulation_run(env_cfg_path, hyperparams):
    # Setup Checkpoint Directories
    save_directory = Path("project_weights") / "baseline_run"
    save_directory.mkdir(parents=True, exist_ok=True)
    
    # Initialize Environment
    simulator = gym.make(id='cityflow-v0', configPath=env_cfg_path, episodeSteps=hyperparams['max_steps'])
    initial_reading = simulator.reset()
    traffic_nodes = sorted(initial_reading.keys())
    
    # Calculate decay factor based on total episodes
    total_eps = hyperparams['episodes']
    hyperparams['decay_eps'] = (hyperparams['min_eps'] / hyperparams['initial_eps']) ** (1.0 / total_eps)
    
    # Initialize Coordinator
    coordinator = GlobalTrafficCoordinator(
        state_size=hyperparams['state_dim'],
        action_size=hyperparams['action_dim'],
        total_agents=len(traffic_nodes),
        config=hyperparams
    )
    
    performance_log = []

    for episode in range(1, total_eps + 1):
        # Reset with random seed
        simulator.seed(np.random.randint(0, 999999))
        raw_state = simulator.reset()
        
        # Format State
        current_state = [np.array(raw_state[node], dtype=np.float32).flatten() for node in traffic_nodes]
        cumulative_score = 0

        for step in range(hyperparams['max_steps']):
            # Act
            action_vector = coordinator.pick_actions(current_state)
            
            # Step Simulator
            raw_next_state, raw_rewards, is_terminal, _ = simulator.step(action_vector)
            
            # Format Next State & Rewards
            next_state = [np.array(raw_next_state[node], dtype=np.float32).flatten() for node in traffic_nodes]
            reward_mapping = dict(raw_rewards)
            reward_vector = [reward_mapping[node] for node in traffic_nodes]
            
            cumulative_score += sum(reward_vector)

            # Record and Learn
            coordinator.record_and_train(current_state, action_vector, next_state, reward_vector, is_terminal)
            
            current_state = next_state
            if is_terminal:
                break

        coordinator.decay_exploration()
        performance_log.append(cumulative_score)
        
        print(f"Run {episode:04d} | Score: {cumulative_score:8.1f} | Exploration Rate: {coordinator.explore_rate:.3f}")

        # Specific Checkpointing
        if episode % hyperparams['save_interval'] == 0:
            ckpt_file = save_directory / f"intersection_brain_ep{episode}.pth"
            torch.save(coordinator.policy_net.state_dict(), ckpt_file)
            print(f"--> Checkpoint secured: {ckpt_file.name}")

    # Final Save
    final_file = save_directory / "intersection_brain_final.pth"
    torch.save(coordinator.policy_net.state_dict(), final_file)
    print(f"\nTraining Complete. Final model stored at {final_file}")
    
    simulator.close()
    return performance_log

# %%
# CELL 6: Configuration and Execution
config_parameters = {
    'episodes': 500,
    'max_steps': 1000,
    'state_dim': 72,
    'action_dim': 9,
    'buffer_limit': 15000, # Per agent, total buffer is 15000 * num_agents
    'batch_sz': 128,
    'update_freq': 4,
    'sync_freq': 8,
    'learning_rate': 1e-4,
    'gamma': 0.99, # Updated from 0.8 to better handle delayed traffic rewards
    'initial_eps': 1.0,
    'min_eps': 0.05,
    'grad_clip': 1.0,
    'save_interval': 250
}

# Run the pipeline
# NOTE: Ensure "../configs/Intersections_4/sample_config.json" exists in your directory
training_history = execute_simulation_run("../configs/Intersections_4/sample_config.json", config_parameters)

# Plotting the Learning Curve
plt.figure(figsize=(10, 5))
plt.plot(training_history, color='teal', linewidth=2)
plt.title("Multi-Agent Traffic Policy Convergence")
plt.xlabel("Episode")
plt.ylabel("Cumulative City Reward")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Run 0001 | Score: -999141.0 | Exploration Rate: 0.994
# Run 0002 | Score: -948936.0 | Exploration Rate: 0.988
# Run 0003 | Score: -945535.2 | Exploration Rate: 0.982
# Run 0004 | Score: -896175.6 | Exploration Rate: 0.976
# Run 0005 | Score: -901290.0 | Exploration Rate: 0.970
# Run 0006 | Score: -899502.6 | Exploration Rate: 0.965
# Run 0007 | Score: -876231.6 | Exploration Rate: 0.959
# Run 0008 | Score: -963849.6 | Exploration Rate: 0.953
# Run 0009 | Score: -913926.0 | Exploration Rate: 0.948
# Run 0010 | Score: -945861.6 | Exploration Rate: 0.942
# Run 0011 | Score: -907155.0 | Exploration Rate: 0.936
# Run 0012 | Score: -927361.2 | Exploration Rate: 0.931
# Run 0013 | Score: -871009.2 | Exploration Rate: 0.925
# Run 0014 | Score: -928238.4 | Exploration Rate: 0.920
# Run 0015 | Score: -910932.6 | Exploration Rate: 0.914
# Run 0016 | Score: -940219.8 | Exploration Rate: 0.909
# Run 0017 | Score: -897278.4 | Exploration Rate: 0.903
# Run 0018 | Score: -862756.2 | Exploration Rate: 0.898
# Run 0019 | Score: -942397.8 | Exploration Rate: 0.892
# Run 0020 | Score: -973314.6 | Exploration Rate: 0.887
# Run 0021 | Score: -983403.0 | Exploration Rate: 0.882
# Run 0022 | Score: -961050.6 | Exploration Rate: 0.877
# Run 0023 | Score: -896584.2 | Exploration Rate: 0.871
# Run 0024 | Score: -918728.4 | Exploration Rate: 0.866
# Run 0025 | Score: -926902.2 | Exploration Rate: 0.861
# Run 0026 | Score: -875611.8 | Exploration Rate: 0.856
# Run 0027 | Score: -883603.2 | Exploration Rate: 0.851
# Run 0028 | Score: -867754.8 | Exploration Rate: 0.846
# Run 0029 | Score: -869641.8 | Exploration Rate: 0.841
# Run 0030 | Score: -866120.4 | Exploration Rate: 0.835
# Run 0031 | Score: -810793.2 | Exploration Rate: 0.830
# Run 0032 | Score: -809131.2 | Exploration Rate: 0.826
# Run 0033 | Score: -807652.2 | Exploration Rate: 0.821
# Run 0034 | Score: -770773.8 | Exploration Rate: 0.816
# Run 0035 | Score: -741450.0 | Exploration Rate: 0.811
# Run 0036 | Score: -782101.2 | Exploration Rate: 0.806
# Run 0037 | Score: -736839.6 | Exploration Rate: 0.801
# Run 0038 | Score: -705805.8 | Exploration Rate: 0.796
# Run 0039 | Score: -667665.0 | Exploration Rate: 0.792
# Run 0040 | Score: -740371.8 | Exploration Rate: 0.787
# Run 0041 | Score: -722226.0 | Exploration Rate: 0.782
# Run 0042 | Score: -672400.8 | Exploration Rate: 0.778
# Run 0043 | Score: -621203.4 | Exploration Rate: 0.773
# Run 0044 | Score: -665426.4 | Exploration Rate: 0.768
# Run 0045 | Score: -577896.6 | Exploration Rate: 0.764
# Run 0046 | Score: -601971.0 | Exploration Rate: 0.759
# Run 0047 | Score: -684945.0 | Exploration Rate: 0.755
# Run 0048 | Score: -787326.0 | Exploration Rate: 0.750
# Run 0049 | Score: -586011.0 | Exploration Rate: 0.746
# Run 0050 | Score: -582865.2 | Exploration Rate: 0.741
# Run 0051 | Score: -574444.2 | Exploration Rate: 0.737
# Run 0052 | Score: -545665.2 | Exploration Rate: 0.732
# Run 0053 | Score: -498961.2 | Exploration Rate: 0.728
# Run 0054 | Score: -510010.8 | Exploration Rate: 0.724
# Run 0055 | Score: -625296.6 | Exploration Rate: 0.719
# Run 0056 | Score: -560298.0 | Exploration Rate: 0.715
# Run 0057 | Score: -521764.2 | Exploration Rate: 0.711
# Run 0058 | Score: -528768.6 | Exploration Rate: 0.706
# Run 0059 | Score: -494417.4 | Exploration Rate: 0.702
# Run 0060 | Score: -515407.8 | Exploration Rate: 0.698
# Run 0061 | Score: -452742.6 | Exploration Rate: 0.694
# Run 0062 | Score: -503682.6 | Exploration Rate: 0.690
# Run 0063 | Score: -481304.4 | Exploration Rate: 0.686
# Run 0064 | Score: -604056.0 | Exploration Rate: 0.682
# Run 0065 | Score: -520383.0 | Exploration Rate: 0.677
# Run 0066 | Score: -451926.0 | Exploration Rate: 0.673
# Run 0067 | Score: -470842.8 | Exploration Rate: 0.669
# Run 0068 | Score: -478639.8 | Exploration Rate: 0.665
# Run 0069 | Score: -509001.0 | Exploration Rate: 0.661
# Run 0070 | Score: -435642.0 | Exploration Rate: 0.657
# Run 0071 | Score: -472143.0 | Exploration Rate: 0.654
# Run 0072 | Score: -525542.4 | Exploration Rate: 0.650
# Run 0073 | Score: -459661.8 | Exploration Rate: 0.646
# Run 0074 | Score: -538550.4 | Exploration Rate: 0.642
# Run 0075 | Score: -496396.2 | Exploration Rate: 0.638
# Run 0076 | Score: -497712.0 | Exploration Rate: 0.634
# Run 0077 | Score: -482942.4 | Exploration Rate: 0.630
# Run 0078 | Score: -446742.0 | Exploration Rate: 0.627
# Run 0079 | Score: -449984.4 | Exploration Rate: 0.623
# Run 0080 | Score: -453010.2 | Exploration Rate: 0.619
# Run 0081 | Score: -467973.6 | Exploration Rate: 0.616
# Run 0082 | Score: -423543.6 | Exploration Rate: 0.612
# Run 0083 | Score: -449938.8 | Exploration Rate: 0.608
# Run 0084 | Score: -387705.0 | Exploration Rate: 0.605
# Run 0085 | Score: -465046.8 | Exploration Rate: 0.601
# Run 0086 | Score: -396328.8 | Exploration Rate: 0.597
# Run 0087 | Score: -498618.0 | Exploration Rate: 0.594
# Run 0088 | Score: -409018.2 | Exploration Rate: 0.590
# Run 0089 | Score: -412484.4 | Exploration Rate: 0.587
# Run 0090 | Score: -441370.8 | Exploration Rate: 0.583
# Run 0091 | Score: -372327.0 | Exploration Rate: 0.580
# Run 0092 | Score: -391661.4 | Exploration Rate: 0.576
# Run 0093 | Score: -405454.2 | Exploration Rate: 0.573
# Run 0094 | Score: -393393.6 | Exploration Rate: 0.569
# Run 0095 | Score: -376790.4 | Exploration Rate: 0.566
# Run 0096 | Score: -350466.0 | Exploration Rate: 0.563
# Run 0097 | Score: -408362.4 | Exploration Rate: 0.559
# Run 0098 | Score: -409812.6 | Exploration Rate: 0.556
# Run 0099 | Score: -386574.0 | Exploration Rate: 0.553
# Run 0100 | Score: -427807.8 | Exploration Rate: 0.549
# Run 0101 | Score: -360891.6 | Exploration Rate: 0.546
# Run 0102 | Score: -380306.4 | Exploration Rate: 0.543
# Run 0103 | Score: -376726.8 | Exploration Rate: 0.539
# Run 0104 | Score: -381381.0 | Exploration Rate: 0.536
# Run 0105 | Score: -337899.6 | Exploration Rate: 0.533
# Run 0106 | Score: -408201.0 | Exploration Rate: 0.530
# Run 0107 | Score: -365931.0 | Exploration Rate: 0.527
# Run 0108 | Score: -388120.8 | Exploration Rate: 0.524
# Run 0109 | Score: -355882.8 | Exploration Rate: 0.520
# Run 0110 | Score: -372856.8 | Exploration Rate: 0.517
# Run 0111 | Score: -394926.6 | Exploration Rate: 0.514
# Run 0112 | Score: -412534.8 | Exploration Rate: 0.511
# Run 0113 | Score: -341552.4 | Exploration Rate: 0.508
# Run 0114 | Score: -355583.4 | Exploration Rate: 0.505
# Run 0115 | Score: -396889.8 | Exploration Rate: 0.502
# Run 0116 | Score: -387496.8 | Exploration Rate: 0.499
# Run 0117 | Score: -382212.0 | Exploration Rate: 0.496
# Run 0118 | Score: -371773.8 | Exploration Rate: 0.493
# Run 0119 | Score: -381703.8 | Exploration Rate: 0.490
# Run 0120 | Score: -395862.0 | Exploration Rate: 0.487
# Run 0121 | Score: -387420.6 | Exploration Rate: 0.484
# Run 0122 | Score: -353451.0 | Exploration Rate: 0.481
# Run 0123 | Score: -347327.4 | Exploration Rate: 0.479
# Run 0124 | Score: -394173.6 | Exploration Rate: 0.476
# Run 0125 | Score: -331215.6 | Exploration Rate: 0.473
# Run 0126 | Score: -364662.6 | Exploration Rate: 0.470
# Run 0127 | Score: -318869.4 | Exploration Rate: 0.467
# Run 0128 | Score: -351630.0 | Exploration Rate: 0.464
# Run 0129 | Score: -367657.2 | Exploration Rate: 0.462
# Run 0130 | Score: -348427.2 | Exploration Rate: 0.459
# Run 0131 | Score: -354636.0 | Exploration Rate: 0.456
# Run 0132 | Score: -343299.6 | Exploration Rate: 0.453
# Run 0133 | Score: -428891.4 | Exploration Rate: 0.451
# Run 0134 | Score: -311581.8 | Exploration Rate: 0.448
# Run 0135 | Score: -336318.0 | Exploration Rate: 0.445
# Run 0136 | Score: -380377.8 | Exploration Rate: 0.443
# Run 0137 | Score: -336576.0 | Exploration Rate: 0.440
# Run 0138 | Score: -331368.0 | Exploration Rate: 0.437
# Run 0139 | Score: -332217.0 | Exploration Rate: 0.435
# Run 0140 | Score: -314280.0 | Exploration Rate: 0.432
# Run 0141 | Score: -343398.6 | Exploration Rate: 0.430
# Run 0142 | Score: -331804.2 | Exploration Rate: 0.427
# Run 0143 | Score: -330381.6 | Exploration Rate: 0.425
# Run 0144 | Score: -347713.2 | Exploration Rate: 0.422
# Run 0145 | Score: -310576.2 | Exploration Rate: 0.419
# Run 0146 | Score: -309710.4 | Exploration Rate: 0.417
# Run 0147 | Score: -355656.6 | Exploration Rate: 0.414
# Run 0148 | Score: -329290.8 | Exploration Rate: 0.412
# Run 0149 | Score: -337006.2 | Exploration Rate: 0.410
# Run 0150 | Score: -368297.4 | Exploration Rate: 0.407
# Run 0151 | Score: -353784.6 | Exploration Rate: 0.405
# Run 0152 | Score: -280564.8 | Exploration Rate: 0.402
# Run 0153 | Score: -292507.2 | Exploration Rate: 0.400
# Run 0154 | Score: -292420.2 | Exploration Rate: 0.397
# Run 0155 | Score: -358071.6 | Exploration Rate: 0.395
# Run 0156 | Score: -335253.6 | Exploration Rate: 0.393
# Run 0157 | Score: -306896.4 | Exploration Rate: 0.390
# Run 0158 | Score: -342757.2 | Exploration Rate: 0.388
# Run 0159 | Score: -325569.0 | Exploration Rate: 0.386
# Run 0160 | Score: -281077.8 | Exploration Rate: 0.383
# Run 0161 | Score: -333811.2 | Exploration Rate: 0.381
# Run 0162 | Score: -314220.6 | Exploration Rate: 0.379
# Run 0163 | Score: -316581.0 | Exploration Rate: 0.377
# Run 0164 | Score: -289086.6 | Exploration Rate: 0.374
# Run 0165 | Score: -309975.6 | Exploration Rate: 0.372
# Run 0166 | Score: -305043.0 | Exploration Rate: 0.370
# Run 0167 | Score: -275113.2 | Exploration Rate: 0.368
# Run 0168 | Score: -345465.6 | Exploration Rate: 0.365
# Run 0169 | Score: -375460.8 | Exploration Rate: 0.363
# Run 0170 | Score: -310966.2 | Exploration Rate: 0.361
# Run 0171 | Score: -350335.2 | Exploration Rate: 0.359
# Run 0172 | Score: -345659.4 | Exploration Rate: 0.357
# Run 0173 | Score: -308769.6 | Exploration Rate: 0.355
# Run 0174 | Score: -276197.4 | Exploration Rate: 0.353
# Run 0175 | Score: -282580.8 | Exploration Rate: 0.350
# Run 0176 | Score: -290984.4 | Exploration Rate: 0.348
# Run 0177 | Score: -318766.2 | Exploration Rate: 0.346
# Run 0178 | Score: -337576.8 | Exploration Rate: 0.344
# Run 0179 | Score: -282889.2 | Exploration Rate: 0.342
# Run 0180 | Score: -280311.6 | Exploration Rate: 0.340
# Run 0181 | Score: -282153.6 | Exploration Rate: 0.338
# Run 0182 | Score: -305357.4 | Exploration Rate: 0.336
# Run 0183 | Score: -304911.6 | Exploration Rate: 0.334
# Run 0184 | Score: -299849.4 | Exploration Rate: 0.332
# Run 0185 | Score: -335269.2 | Exploration Rate: 0.330
# Run 0186 | Score: -340968.6 | Exploration Rate: 0.328
# Run 0187 | Score: -283141.8 | Exploration Rate: 0.326
# Run 0188 | Score: -307774.8 | Exploration Rate: 0.324
# Run 0189 | Score: -290773.2 | Exploration Rate: 0.322
# Run 0190 | Score: -299043.6 | Exploration Rate: 0.320
# Run 0191 | Score: -265016.4 | Exploration Rate: 0.318
# Run 0192 | Score: -319741.2 | Exploration Rate: 0.317
# Run 0193 | Score: -334953.6 | Exploration Rate: 0.315
# Run 0194 | Score: -296389.8 | Exploration Rate: 0.313
# Run 0195 | Score: -357661.8 | Exploration Rate: 0.311
# Run 0196 | Score: -353817.6 | Exploration Rate: 0.309
# Run 0197 | Score: -305394.6 | Exploration Rate: 0.307
# Run 0198 | Score: -293705.4 | Exploration Rate: 0.305
# Run 0199 | Score: -303097.2 | Exploration Rate: 0.304
# Run 0200 | Score: -294855.6 | Exploration Rate: 0.302
# Run 0201 | Score: -327874.2 | Exploration Rate: 0.300
# Run 0202 | Score: -336136.8 | Exploration Rate: 0.298
# Run 0203 | Score: -295473.0 | Exploration Rate: 0.296
# Run 0204 | Score: -297342.0 | Exploration Rate: 0.295
# Run 0205 | Score: -282321.6 | Exploration Rate: 0.293
# Run 0206 | Score: -254047.2 | Exploration Rate: 0.291
# Run 0207 | Score: -299812.2 | Exploration Rate: 0.289
# Run 0208 | Score: -308490.6 | Exploration Rate: 0.288
# Run 0209 | Score: -293608.8 | Exploration Rate: 0.286
# Run 0210 | Score: -312493.2 | Exploration Rate: 0.284
# Run 0211 | Score: -274437.0 | Exploration Rate: 0.282
# Run 0212 | Score: -285848.4 | Exploration Rate: 0.281
# Run 0213 | Score: -242524.8 | Exploration Rate: 0.279
# Run 0214 | Score: -265342.2 | Exploration Rate: 0.277
# Run 0215 | Score: -308203.2 | Exploration Rate: 0.276
# Run 0216 | Score: -259842.0 | Exploration Rate: 0.274
# Run 0217 | Score: -257602.2 | Exploration Rate: 0.272
# Run 0218 | Score: -287899.8 | Exploration Rate: 0.271
# Run 0219 | Score: -310461.0 | Exploration Rate: 0.269
# Run 0220 | Score: -272200.8 | Exploration Rate: 0.268
# Run 0221 | Score: -314029.8 | Exploration Rate: 0.266
# Run 0222 | Score: -303518.4 | Exploration Rate: 0.264
# Run 0223 | Score: -301101.6 | Exploration Rate: 0.263
# Run 0224 | Score: -279868.2 | Exploration Rate: 0.261
# Run 0225 | Score: -279167.4 | Exploration Rate: 0.260
# Run 0226 | Score: -313230.6 | Exploration Rate: 0.258
# Run 0227 | Score: -316234.2 | Exploration Rate: 0.257
# Run 0228 | Score: -279582.0 | Exploration Rate: 0.255
# Run 0229 | Score: -273463.8 | Exploration Rate: 0.254
# Run 0230 | Score: -277780.8 | Exploration Rate: 0.252
# Run 0231 | Score: -258808.8 | Exploration Rate: 0.251
# Run 0232 | Score: -284561.4 | Exploration Rate: 0.249
# Run 0233 | Score: -294860.4 | Exploration Rate: 0.248
# Run 0234 | Score: -285168.6 | Exploration Rate: 0.246
# Run 0235 | Score: -280067.4 | Exploration Rate: 0.245
# Run 0236 | Score: -336153.6 | Exploration Rate: 0.243
# Run 0237 | Score: -296392.2 | Exploration Rate: 0.242
# Run 0238 | Score: -303744.0 | Exploration Rate: 0.240
# Run 0239 | Score: -321987.6 | Exploration Rate: 0.239
# Run 0240 | Score: -299269.8 | Exploration Rate: 0.237
# Run 0241 | Score: -300930.0 | Exploration Rate: 0.236
# Run 0242 | Score: -330681.6 | Exploration Rate: 0.235
# Run 0243 | Score: -302469.6 | Exploration Rate: 0.233
# Run 0244 | Score: -259479.6 | Exploration Rate: 0.232
# Run 0245 | Score: -283652.4 | Exploration Rate: 0.230
# Run 0246 | Score: -272253.0 | Exploration Rate: 0.229
# Run 0247 | Score: -275163.0 | Exploration Rate: 0.228
# Run 0248 | Score: -251555.4 | Exploration Rate: 0.226
# Run 0249 | Score: -304197.6 | Exploration Rate: 0.225
# Run 0250 | Score: -277571.4 | Exploration Rate: 0.224
# --> Checkpoint secured: intersection_brain_ep250.pth
# Run 0251 | Score: -280154.4 | Exploration Rate: 0.222
# Run 0252 | Score: -333013.2 | Exploration Rate: 0.221
# Run 0253 | Score: -305370.6 | Exploration Rate: 0.220
# Run 0254 | Score: -289565.4 | Exploration Rate: 0.218
# Run 0255 | Score: -285126.6 | Exploration Rate: 0.217
# Run 0256 | Score: -257122.2 | Exploration Rate: 0.216
# Run 0257 | Score: -286825.2 | Exploration Rate: 0.214
# Run 0258 | Score: -306336.6 | Exploration Rate: 0.213
# Run 0259 | Score: -286854.0 | Exploration Rate: 0.212
# Run 0260 | Score: -269721.0 | Exploration Rate: 0.211
# Run 0261 | Score: -280927.8 | Exploration Rate: 0.209
# Run 0262 | Score: -306971.4 | Exploration Rate: 0.208
# Run 0263 | Score: -356250.0 | Exploration Rate: 0.207
# Run 0264 | Score: -309645.0 | Exploration Rate: 0.206
# Run 0265 | Score: -278038.2 | Exploration Rate: 0.204
# Run 0266 | Score: -246133.2 | Exploration Rate: 0.203
# Run 0267 | Score: -344428.2 | Exploration Rate: 0.202
# Run 0268 | Score: -332131.8 | Exploration Rate: 0.201
# Run 0269 | Score: -313635.0 | Exploration Rate: 0.200
# Run 0270 | Score: -396044.4 | Exploration Rate: 0.198
# Run 0271 | Score: -277680.6 | Exploration Rate: 0.197
# Run 0272 | Score: -302525.4 | Exploration Rate: 0.196
# Run 0273 | Score: -263141.4 | Exploration Rate: 0.195
# Run 0274 | Score: -317192.4 | Exploration Rate: 0.194
# Run 0275 | Score: -272331.6 | Exploration Rate: 0.193
# Run 0276 | Score: -297337.8 | Exploration Rate: 0.191
# Run 0277 | Score: -256637.4 | Exploration Rate: 0.190
# Run 0278 | Score: -262511.4 | Exploration Rate: 0.189
# Run 0279 | Score: -287672.4 | Exploration Rate: 0.188
# Run 0280 | Score: -280956.6 | Exploration Rate: 0.187
# Run 0281 | Score: -276816.0 | Exploration Rate: 0.186
# Run 0282 | Score: -277238.4 | Exploration Rate: 0.185
# Run 0283 | Score: -311695.8 | Exploration Rate: 0.183
# Run 0284 | Score: -285692.4 | Exploration Rate: 0.182
# Run 0285 | Score: -243404.4 | Exploration Rate: 0.181
# Run 0286 | Score: -302257.2 | Exploration Rate: 0.180
# Run 0287 | Score: -313761.6 | Exploration Rate: 0.179
# Run 0288 | Score: -288771.6 | Exploration Rate: 0.178
# Run 0289 | Score: -293893.2 | Exploration Rate: 0.177
# Run 0290 | Score: -301712.4 | Exploration Rate: 0.176
# Run 0291 | Score: -306700.2 | Exploration Rate: 0.175
# Run 0292 | Score: -295041.6 | Exploration Rate: 0.174
# Run 0293 | Score: -296622.0 | Exploration Rate: 0.173
# Run 0294 | Score: -295595.4 | Exploration Rate: 0.172
# Run 0295 | Score: -275217.6 | Exploration Rate: 0.171
# Run 0296 | Score: -286857.6 | Exploration Rate: 0.170
# Run 0297 | Score: -256044.0 | Exploration Rate: 0.169
# Run 0298 | Score: -239050.2 | Exploration Rate: 0.168
# Run 0299 | Score: -372643.2 | Exploration Rate: 0.167
# Run 0300 | Score: -252949.8 | Exploration Rate: 0.166
# Run 0301 | Score: -275687.4 | Exploration Rate: 0.165
# Run 0302 | Score: -282901.2 | Exploration Rate: 0.164
# Run 0303 | Score: -286759.8 | Exploration Rate: 0.163
# Run 0304 | Score: -263370.0 | Exploration Rate: 0.162
# Run 0305 | Score: -272832.6 | Exploration Rate: 0.161
# Run 0306 | Score: -305135.4 | Exploration Rate: 0.160
# Run 0307 | Score: -260643.6 | Exploration Rate: 0.159
# Run 0308 | Score: -249887.4 | Exploration Rate: 0.158
# Run 0309 | Score: -260772.0 | Exploration Rate: 0.157
# Run 0310 | Score: -242599.8 | Exploration Rate: 0.156
# Run 0311 | Score: -236141.4 | Exploration Rate: 0.155
# Run 0312 | Score: -302571.6 | Exploration Rate: 0.154
# Run 0313 | Score: -383427.6 | Exploration Rate: 0.153
# Run 0314 | Score: -255758.4 | Exploration Rate: 0.152
# Run 0315 | Score: -295836.6 | Exploration Rate: 0.151
# Run 0316 | Score: -1502655.0 | Exploration Rate: 0.151
# Run 0317 | Score: -275046.0 | Exploration Rate: 0.150
# Run 0318 | Score: -262347.6 | Exploration Rate: 0.149
# Run 0319 | Score: -295338.6 | Exploration Rate: 0.148
# Run 0320 | Score: -366368.4 | Exploration Rate: 0.147
# Run 0321 | Score: -273917.4 | Exploration Rate: 0.146
# Run 0322 | Score: -264876.0 | Exploration Rate: 0.145
# Run 0323 | Score: -277628.4 | Exploration Rate: 0.144
# Run 0324 | Score: -310101.0 | Exploration Rate: 0.144
# Run 0325 | Score: -283544.4 | Exploration Rate: 0.143
# Run 0326 | Score: -267869.4 | Exploration Rate: 0.142
# Run 0327 | Score: -306442.8 | Exploration Rate: 0.141
# Run 0328 | Score: -264343.8 | Exploration Rate: 0.140
# Run 0329 | Score: -281475.6 | Exploration Rate: 0.139
# Run 0330 | Score: -285079.2 | Exploration Rate: 0.138
# Run 0331 | Score: -291465.0 | Exploration Rate: 0.138
# Run 0332 | Score: -275355.6 | Exploration Rate: 0.137
# Run 0333 | Score: -250302.0 | Exploration Rate: 0.136
# Run 0334 | Score: -264895.8 | Exploration Rate: 0.135
# Run 0335 | Score: -273468.6 | Exploration Rate: 0.134
# Run 0336 | Score: -278932.8 | Exploration Rate: 0.134
# Run 0337 | Score: -314749.2 | Exploration Rate: 0.133
# Run 0338 | Score: -252057.6 | Exploration Rate: 0.132
# Run 0339 | Score: -307045.2 | Exploration Rate: 0.131
# Run 0340 | Score: -562882.2 | Exploration Rate: 0.130
# Run 0341 | Score: -252699.6 | Exploration Rate: 0.130
# Run 0342 | Score: -315753.6 | Exploration Rate: 0.129
# Run 0343 | Score: -251640.0 | Exploration Rate: 0.128
# Run 0344 | Score: -250407.0 | Exploration Rate: 0.127
# Run 0345 | Score: -242238.6 | Exploration Rate: 0.127
# Run 0346 | Score: -323002.2 | Exploration Rate: 0.126
# Run 0347 | Score: -283621.8 | Exploration Rate: 0.125
# Run 0348 | Score: -290207.4 | Exploration Rate: 0.124
# Run 0349 | Score: -238306.2 | Exploration Rate: 0.124
# Run 0350 | Score: -257983.8 | Exploration Rate: 0.123
# Run 0351 | Score: -312945.6 | Exploration Rate: 0.122
# Run 0352 | Score: -296395.2 | Exploration Rate: 0.121
# Run 0353 | Score: -283583.4 | Exploration Rate: 0.121
# Run 0354 | Score: -310990.8 | Exploration Rate: 0.120
# Run 0355 | Score: -341437.8 | Exploration Rate: 0.119
# Run 0356 | Score: -266304.0 | Exploration Rate: 0.118
# Run 0357 | Score: -290200.2 | Exploration Rate: 0.118
# Run 0358 | Score: -344954.4 | Exploration Rate: 0.117
# Run 0359 | Score: -291275.4 | Exploration Rate: 0.116
# Run 0360 | Score: -263220.0 | Exploration Rate: 0.116
# Run 0361 | Score: -306947.4 | Exploration Rate: 0.115
# Run 0362 | Score: -342243.6 | Exploration Rate: 0.114
# Run 0363 | Score: -297501.0 | Exploration Rate: 0.114
# Run 0364 | Score: -269416.8 | Exploration Rate: 0.113
# Run 0365 | Score: -235816.8 | Exploration Rate: 0.112
# Run 0366 | Score: -265744.8 | Exploration Rate: 0.112
# Run 0367 | Score: -261271.8 | Exploration Rate: 0.111
# Run 0368 | Score: -240274.2 | Exploration Rate: 0.110
# Run 0369 | Score: -261778.8 | Exploration Rate: 0.110
# Run 0370 | Score: -228317.4 | Exploration Rate: 0.109
# Run 0371 | Score: -265866.0 | Exploration Rate: 0.108
# Run 0372 | Score: -221382.6 | Exploration Rate: 0.108
# Run 0373 | Score: -232977.0 | Exploration Rate: 0.107
# Run 0374 | Score: -218847.6 | Exploration Rate: 0.106
# Run 0375 | Score: -243981.0 | Exploration Rate: 0.106
# Run 0376 | Score: -283327.2 | Exploration Rate: 0.105
# Run 0377 | Score: -201428.4 | Exploration Rate: 0.104
# Run 0378 | Score: -250005.0 | Exploration Rate: 0.104
# Run 0379 | Score: -243247.2 | Exploration Rate: 0.103
# Run 0380 | Score: -300520.2 | Exploration Rate: 0.103
# Run 0381 | Score: -360510.6 | Exploration Rate: 0.102
# Run 0382 | Score: -250615.2 | Exploration Rate: 0.101
# Run 0383 | Score: -223542.6 | Exploration Rate: 0.101
# Run 0384 | Score: -280798.8 | Exploration Rate: 0.100
# Run 0385 | Score: -266125.8 | Exploration Rate: 0.100
# Run 0386 | Score: -381580.8 | Exploration Rate: 0.099
# Run 0387 | Score: -308338.8 | Exploration Rate: 0.098
# Run 0388 | Score: -253047.6 | Exploration Rate: 0.098
# Run 0389 | Score: -274836.6 | Exploration Rate: 0.097
# Run 0390 | Score: -280785.0 | Exploration Rate: 0.097
# Run 0391 | Score: -268585.8 | Exploration Rate: 0.096
# Run 0392 | Score: -249298.2 | Exploration Rate: 0.095
# Run 0393 | Score: -603318.6 | Exploration Rate: 0.095
# Run 0394 | Score: -268135.2 | Exploration Rate: 0.094
# Run 0395 | Score: -269926.8 | Exploration Rate: 0.094
# Run 0396 | Score: -528119.4 | Exploration Rate: 0.093
# Run 0397 | Score: -400231.2 | Exploration Rate: 0.093
# Run 0398 | Score: -298094.4 | Exploration Rate: 0.092
# Run 0399 | Score: -289659.6 | Exploration Rate: 0.092
# Run 0400 | Score: -273529.2 | Exploration Rate: 0.091
# Run 0401 | Score: -262356.6 | Exploration Rate: 0.090
# Run 0402 | Score: -471815.4 | Exploration Rate: 0.090
# Run 0403 | Score: -628937.4 | Exploration Rate: 0.089
# Run 0404 | Score: -237907.2 | Exploration Rate: 0.089
# Run 0405 | Score: -226237.8 | Exploration Rate: 0.088
# Run 0406 | Score: -224446.8 | Exploration Rate: 0.088
# Run 0407 | Score: -242464.2 | Exploration Rate: 0.087
# Run 0408 | Score: -269509.2 | Exploration Rate: 0.087
# Run 0409 | Score: -262489.8 | Exploration Rate: 0.086
# Run 0410 | Score: -258672.6 | Exploration Rate: 0.086
# Run 0411 | Score: -369123.0 | Exploration Rate: 0.085
# Run 0412 | Score: -267565.2 | Exploration Rate: 0.085
# Run 0413 | Score: -252893.4 | Exploration Rate: 0.084
# Run 0414 | Score: -251508.0 | Exploration Rate: 0.084
# Run 0415 | Score: -233408.4 | Exploration Rate: 0.083
# Run 0416 | Score: -302833.2 | Exploration Rate: 0.083
# Run 0417 | Score: -240366.0 | Exploration Rate: 0.082
# Run 0418 | Score: -455074.8 | Exploration Rate: 0.082
# Run 0419 | Score: -260886.6 | Exploration Rate: 0.081
# Run 0420 | Score: -358921.8 | Exploration Rate: 0.081
# Run 0421 | Score: -255215.4 | Exploration Rate: 0.080
# Run 0422 | Score: -254955.6 | Exploration Rate: 0.080
# Run 0423 | Score: -342661.2 | Exploration Rate: 0.079
# Run 0424 | Score: -241542.0 | Exploration Rate: 0.079
# Run 0425 | Score: -371098.2 | Exploration Rate: 0.078
# Run 0426 | Score: -278496.6 | Exploration Rate: 0.078
# Run 0427 | Score: -475180.2 | Exploration Rate: 0.077
# Run 0428 | Score: -249102.0 | Exploration Rate: 0.077
# Run 0429 | Score: -342787.8 | Exploration Rate: 0.077
# Run 0430 | Score: -239342.4 | Exploration Rate: 0.076
# Run 0431 | Score: -281539.8 | Exploration Rate: 0.076
# Run 0432 | Score: -272265.6 | Exploration Rate: 0.075
# Run 0433 | Score: -283931.4 | Exploration Rate: 0.075
# Run 0434 | Score: -296250.0 | Exploration Rate: 0.074
# Run 0435 | Score: -292310.4 | Exploration Rate: 0.074
# Run 0436 | Score: -276046.2 | Exploration Rate: 0.073
# Run 0437 | Score: -320275.2 | Exploration Rate: 0.073
# Run 0438 | Score: -297121.8 | Exploration Rate: 0.072
# Run 0439 | Score: -319750.2 | Exploration Rate: 0.072
# Run 0440 | Score: -280241.4 | Exploration Rate: 0.072
# Run 0441 | Score: -220170.0 | Exploration Rate: 0.071
# Run 0442 | Score: -256297.2 | Exploration Rate: 0.071
# Run 0443 | Score: -356126.4 | Exploration Rate: 0.070
# Run 0444 | Score: -424972.2 | Exploration Rate: 0.070
# Run 0445 | Score: -460221.0 | Exploration Rate: 0.070
# Run 0446 | Score: -310320.0 | Exploration Rate: 0.069
# Run 0447 | Score: -311295.0 | Exploration Rate: 0.069
# Run 0448 | Score: -262318.8 | Exploration Rate: 0.068
# Run 0449 | Score: -271869.0 | Exploration Rate: 0.068
# Run 0450 | Score: -236803.8 | Exploration Rate: 0.067
# Run 0451 | Score: -240608.4 | Exploration Rate: 0.067
# Run 0452 | Score: -254632.2 | Exploration Rate: 0.067
# Run 0453 | Score: -286421.4 | Exploration Rate: 0.066
# Run 0454 | Score: -320364.0 | Exploration Rate: 0.066
# Run 0455 | Score: -324879.0 | Exploration Rate: 0.065
# Run 0456 | Score: -222105.6 | Exploration Rate: 0.065
# Run 0457 | Score: -330932.4 | Exploration Rate: 0.065
# Run 0458 | Score: -248837.4 | Exploration Rate: 0.064
# Run 0459 | Score: -387745.2 | Exploration Rate: 0.064
# Run 0460 | Score: -289371.6 | Exploration Rate: 0.064
# Run 0461 | Score: -249972.0 | Exploration Rate: 0.063
# Run 0462 | Score: -223960.2 | Exploration Rate: 0.063
# Run 0463 | Score: -300500.4 | Exploration Rate: 0.062
# Run 0464 | Score: -246316.8 | Exploration Rate: 0.062
# Run 0465 | Score: -225318.6 | Exploration Rate: 0.062
# Run 0466 | Score: -344877.0 | Exploration Rate: 0.061
# Run 0467 | Score: -267796.2 | Exploration Rate: 0.061
# Run 0468 | Score: -252494.4 | Exploration Rate: 0.061
# Run 0469 | Score: -255249.6 | Exploration Rate: 0.060
# Run 0470 | Score: -247499.4 | Exploration Rate: 0.060
# Run 0471 | Score: -245207.4 | Exploration Rate: 0.059
# Run 0472 | Score: -302546.4 | Exploration Rate: 0.059
# Run 0473 | Score: -230190.0 | Exploration Rate: 0.059
# Run 0474 | Score: -275995.2 | Exploration Rate: 0.058
# Run 0475 | Score: -224512.8 | Exploration Rate: 0.058
# Run 0476 | Score: -294730.8 | Exploration Rate: 0.058
# Run 0477 | Score: -278732.4 | Exploration Rate: 0.057
# Run 0478 | Score: -275029.2 | Exploration Rate: 0.057
# Run 0479 | Score: -247069.8 | Exploration Rate: 0.057
# Run 0480 | Score: -247279.8 | Exploration Rate: 0.056
# Run 0481 | Score: -275842.2 | Exploration Rate: 0.056
# Run 0482 | Score: -216252.0 | Exploration Rate: 0.056
# Run 0483 | Score: -267360.0 | Exploration Rate: 0.055
# Run 0484 | Score: -217896.6 | Exploration Rate: 0.055
# Run 0485 | Score: -226648.8 | Exploration Rate: 0.055
# Run 0486 | Score: -246255.0 | Exploration Rate: 0.054
# Run 0487 | Score: -260424.0 | Exploration Rate: 0.054
# Run 0488 | Score: -223202.4 | Exploration Rate: 0.054
# Run 0489 | Score: -264317.4 | Exploration Rate: 0.053
# Run 0490 | Score: -234826.8 | Exploration Rate: 0.053
# Run 0491 | Score: -224419.8 | Exploration Rate: 0.053
# Run 0492 | Score: -265567.8 | Exploration Rate: 0.052
# Run 0493 | Score: -246231.6 | Exploration Rate: 0.052
# Run 0494 | Score: -283554.6 | Exploration Rate: 0.052
# Run 0495 | Score: -247399.8 | Exploration Rate: 0.052
# Run 0496 | Score: -266804.4 | Exploration Rate: 0.051
# Run 0497 | Score: -279114.6 | Exploration Rate: 0.051
# Run 0498 | Score: -217698.6 | Exploration Rate: 0.051
# Run 0499 | Score: -339314.4 | Exploration Rate: 0.050
# Run 0500 | Score: -245953.2 | Exploration Rate: 0.050
# --> Checkpoint secured: intersection_brain_ep500.pth
#
# Training Complete. Final model stored at project_weights/baseline_run/intersection_brain_final.pth
